# %% [markdown]
# # Convolutional Autoencoder
#
# Sticking with the MNIST dataset, let's improve our autoencoder's performance using convolutional layers. Again, loading modules and the data.

# %%
# %matplotlib inline

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', validation_size=0)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
img = mnist.train.images[2]
plt.imshow(img.reshape((28, 28)), cmap='Greys_r')

# %% [markdown]
# ## Network Architecture
#
# The encoder part of the network will be a typical convolutional pyramid. Each convolutional layer will be followed by a max-pooling layer to reduce the dimensions of the layers. The decoder though might be something new to you. The decoder needs to convert from a narrow representation to a wide reconstructed image. For example, the representation could be a 4x4x8 max-pool layer. This is the output of the encoder, but also the input to the decoder. We want to get a 28x28x1 image out from the decoder so we need to work our way back up from the narrow decoder input layer. A schematic of the network is shown below.
#
# <img src='assets/convolutional_autoencoder.png' width=500px>
#
# Here our final encoder layer has size 4x4x8 = 128. The original images have size 28x28 = 784, so the encoded vector is roughly 16% the size of the original image. These are just suggested sizes for each of the layers. Feel free to change the depths and sizes, but remember our goal here is to find a small representation of the input data.
#
# ### What's going on with the decoder
#
# Okay, so the decoder has these "Upsample" layers that you might not have seen before. First off, I'll discuss a bit what these layers *aren't*. Usually, you'll see **transposed convolution** layers used to increase the width and height of the layers. They work almost exactly the same as convolutional layers, but in reverse. A stride in the input layer results in a larger stride in the transposed convolution layer. For example, if you have a 3x3 kernel, a 3x3 patch in the input layer will be reduced to one unit in a convolutional layer. Comparatively, one unit in the input layer will be expanded to a 3x3 path in a transposed convolution layer. The TensorFlow API provides us with an easy way to create the layers, [`tf.nn.conv2d_transpose`](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d_transpose).
#
# However, transposed convolution layers can lead to artifacts in the final images, such as checkerboard patterns. This is due to overlap in the kernels which can be avoided by setting the stride and kernel size equal. In [this Distill article](http://distill.pub/2016/deconv-checkerboard/) from Augustus Odena, *et al*, the authors show that these checkerboard artifacts can be avoided by resizing the layers using nearest neighbor or bilinear interpolation (upsampling) followed by a convolutional layer. In TensorFlow, this is easily done with [`tf.image.resize_images`](https://www.tensorflow.org/versions/r1.1/api_docs/python/tf/image/resize_images), followed by a convolution. Be sure to read the Distill article to get a better understanding of deconvolutional layers and why we're using upsampling.
#
# > **Exercise:** Build the network shown above. Remember that a convolutional layer with strides of 1 and 'same' padding won't reduce the height and width. That is, if the input is 28x28 and the convolution layer has stride = 1 and 'same' padding, the convolutional layer will also be 28x28. The max-pool layers are used the reduce the width and height. A stride of 2 will reduce the size by a factor of 2. Odena *et al* claim that nearest neighbor interpolation works best for the upsampling, so make sure to include that as a parameter in `tf.image.resize_images` or use [`tf.image.resize_nearest_neighbor`]( `https://www.tensorflow.org/api_docs/python/tf/image/resize_nearest_neighbor). For convolutional layers, use [`tf.layers.conv2d`](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d). For example, you would write `conv1 = tf.layers.conv2d(inputs, 32, (5,5), padding='same', activation=tf.nn.relu)` for a layer with a depth of 32, a 5x5 kernel, stride of (1,1), padding is 'same', and a ReLU activation. Similarly, for the max-pool layers, use [`tf.layers.max_pooling2d`](https://www.tensorflow.org/api_docs/python/tf/layers/max_pooling2d).

# %%
learning_rate = 0.001
# Input and target placeholders
inputs_ = tf.placeholder(tf.float32, [None, 28, 28, 1])
targets_ = tf.placeholder(tf.float32, [None, 28, 28, 1])

### Encoder
conv1 = tf.layers.conv2d(inputs_, 16, [2, 2], padding='same', activation=tf.nn.relu)
# Now 28x28x16
maxpool1 = tf.layers.max_pooling2d(conv1, [2, 2], 2)
# Now 14x14x16
conv2 = tf.layers.conv2d(maxpool1, 16, [2, 2], padding='same', activation=tf.nn.relu)
# Now 14x14x8
maxpool2 = tf.layers.max_pooling2d(conv2, [2, 2], 2)
# Now 7x7x8
conv3 = tf.layers.conv2d(maxpool2, 8, [7, 7], padding='same', activation=tf.nn.relu)
# Now 7x7x8
encoded = tf.layers.max_pooling2d(conv3, [4, 4], 1)
# Now 4x4x8

### Decoder
upsample1 = tf.image.resize_images(encoded, [7, 7])
# Now 7x7x8
conv4 = tf.layers.conv2d(upsample1, 8, [2, 2], padding='same', activation=tf.nn.relu)
# Now 7x7x8
upsample2 = tf.image.resize_images(conv4, [14, 14])
# Now 14x14x8
conv5 = tf.layers.conv2d(upsample2, 8, [2, 2], padding='same', activation=tf.nn.relu)
# Now 14x14x8
upsample3 = tf.image.resize_images(conv5, [28, 28])
# Now 28x28x8
conv6 = tf.layers.conv2d(upsample3, 16, [2, 2], padding='same', activation=tf.nn.relu)
# Now 28x28x16

logits = tf.layers.conv2d(conv6, 1, [2, 2], padding='same')
#Now 28x28x1

# Pass logits through sigmoid to get reconstructed image
decoded = tf.nn.sigmoid(logits)

# Pass logits through sigmoid and calculate the cross-entropy loss
loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=targets_)

# Get cost and define the optimizer
cost = tf.reduce_mean(loss)
opt = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %% [markdown]
# ## Training
#
# As before, here we'll train the network. Instead of flattening the images though, we can pass them in as 28x28x1 arrays.

# %%
sess = tf.Session()

# %%
epochs = 10
batch_size = 200
sess.run(tf.global_variables_initializer())
for e in range(epochs):
    for ii in range(mnist.train.num_examples//batch_size):
        batch = mnist.train.next_batch(batch_size)
        imgs = batch[0].reshape((-1, 28, 28, 1))
        batch_cost, _ = sess.run([cost, opt], feed_dict={inputs_: imgs,
                                                         targets_: imgs})

        print("Epoch: {}/{}...".format(e+1, epochs),
              "Training loss: {:.4f}".format(batch_cost))
# Out:
# Epoch: 1/10... Training loss: 0.7052
# Epoch: 1/10... Training loss: 0.6964
# Epoch: 1/10... Training loss: 0.6932
# Epoch: 1/10... Training loss: 0.6906
# Epoch: 1/10... Training loss: 0.6881
# Epoch: 1/10... Training loss: 0.6854
# Epoch: 1/10... Training loss: 0.6828
# Epoch: 1/10... Training loss: 0.6802
# Epoch: 1/10... Training loss: 0.6773
# Epoch: 1/10... Training loss: 0.6739
# Epoch: 1/10... Training loss: 0.6702
# Epoch: 1/10... Training loss: 0.6655
# Epoch: 1/10... Training loss: 0.6598
# Epoch: 1/10... Training loss: 0.6535
# Epoch: 1/10... Training loss: 0.6461
# Epoch: 1/10... Training loss: 0.6367
# Epoch: 1/10... Training loss: 0.6281
# Epoch: 1/10... Training loss: 0.6158
# Epoch: 1/10... Training loss: 0.6040
# Epoch: 1/10... Training loss: 0.5895
# Epoch: 1/10... Training loss: 0.5754
# Epoch: 1/10... Training loss: 0.5565
# Epoch: 1/10... Training loss: 0.5405
# Epoch: 1/10... Training loss: 0.5203
# Epoch: 1/10... Training loss: 0.5082
# Epoch: 1/10... Training loss: 0.4982
# Epoch: 1/10... Training loss: 0.4869
# Epoch: 1/10... Training loss: 0.4870
# Epoch: 1/10... Training loss: 0.4918
# Epoch: 1/10... Training loss: 0.4952
# Epoch: 1/10... Training loss: 0.4901
# Epoch: 1/10... Training loss: 0.5043
# Epoch: 1/10... Training loss: 0.4861
# Epoch: 1/10... Training loss: 0.4884
# Epoch: 1/10... Training loss: 0.4740
# Epoch: 1/10... Training loss: 0.4720
# Epoch: 1/10... Training loss: 0.4515
# Epoch: 1/10... Training loss: 0.4525
# Epoch: 1/10... Training loss: 0.4507
# Epoch: 1/10... Training loss: 0.4490
# Epoch: 1/10... Training loss: 0.4438
# Epoch: 1/10... Training loss: 0.4509
# Epoch: 1/10... Training loss: 0.4448
# Epoch: 1/10... Training loss: 0.4405
# Epoch: 1/10... Training loss: 0.4369
# Epoch: 1/10... Training loss: 0.4346
# Epoch: 1/10... Training loss: 0.4376
# Epoch: 1/10... Training loss: 0.4346
# Epoch: 1/10... Training loss: 0.4154
# Epoch: 1/10... Training loss: 0.4160
# Epoch: 1/10... Training loss: 0.4196
# Epoch: 1/10... Training loss: 0.4066
# Epoch: 1/10... Training loss: 0.4032
# Epoch: 1/10... Training loss: 0.4209
# Epoch: 1/10... Training loss: 0.4046
# Epoch: 1/10... Training loss: 0.4111
# Epoch: 1/10... Training loss: 0.3942
# Epoch: 1/10... Training loss: 0.3944
# Epoch: 1/10... Training loss: 0.3903
# Epoch: 1/10... Training loss: 0.3822
# Epoch: 1/10... Training loss: 0.3997
# Epoch: 1/10... Training loss: 0.3893
# Epoch: 1/10... Training loss: 0.3989
# Epoch: 1/10... Training loss: 0.3778
# Epoch: 1/10... Training loss: 0.3797
# Epoch: 1/10... Training loss: 0.3841
# Epoch: 1/10... Training loss: 0.3685
# Epoch: 1/10... Training loss: 0.3714
# Epoch: 1/10... Training loss: 0.3757
# Epoch: 1/10... Training loss: 0.3598
# Epoch: 1/10... Training loss: 0.3732
# Epoch: 1/10... Training loss: 0.3763
# Epoch: 1/10... Training loss: 0.3645
# Epoch: 1/10... Training loss: 0.3751
# Epoch: 1/10... Training loss: 0.3582
# Epoch: 1/10... Training loss: 0.3678
# Epoch: 1/10... Training loss: 0.3518
# Epoch: 1/10... Training loss: 0.3494
# Epoch: 1/10... Training loss: 0.3466
# Epoch: 1/10... Training loss: 0.3555
# Epoch: 1/10... Training loss: 0.3515
# Epoch: 1/10... Training loss: 0.3487
# Epoch: 1/10... Training loss: 0.3461
# Epoch: 1/10... Training loss: 0.3486
# Epoch: 1/10... Training loss: 0.3460
# Epoch: 1/10... Training loss: 0.3410
# Epoch: 1/10... Training loss: 0.3419
# Epoch: 1/10... Training loss: 0.3338
# Epoch: 1/10... Training loss: 0.3370
# Epoch: 1/10... Training loss: 0.3361
# Epoch: 1/10... Training loss: 0.3346
# Epoch: 1/10... Training loss: 0.3280
# Epoch: 1/10... Training loss: 0.3214
# Epoch: 1/10... Training loss: 0.3232
# Epoch: 1/10... Training loss: 0.3274
# Epoch: 1/10... Training loss: 0.3283
# Epoch: 1/10... Training loss: 0.3265
# Epoch: 1/10... Training loss: 0.3218
# Epoch: 1/10... Training loss: 0.3271
# Epoch: 1/10... Training loss: 0.3129
# Epoch: 1/10... Training loss: 0.3123
# Epoch: 1/10... Training loss: 0.3132
# Epoch: 1/10... Training loss: 0.3220
# Epoch: 1/10... Training loss: 0.3229
# Epoch: 1/10... Training loss: 0.3155
# Epoch: 1/10... Training loss: 0.3072
# Epoch: 1/10... Training loss: 0.3111
# Epoch: 1/10... Training loss: 0.3066
# Epoch: 1/10... Training loss: 0.3008
# Epoch: 1/10... Training loss: 0.3021
# Epoch: 1/10... Training loss: 0.3060
# Epoch: 1/10... Training loss: 0.3002
# Epoch: 1/10... Training loss: 0.2975
# Epoch: 1/10... Training loss: 0.3086
# Epoch: 1/10... Training loss: 0.2983
# Epoch: 1/10... Training loss: 0.3047
# Epoch: 1/10... Training loss: 0.2921
# Epoch: 1/10... Training loss: 0.2996
# Epoch: 1/10... Training loss: 0.2838
# Epoch: 1/10... Training loss: 0.2857
# Epoch: 1/10... Training loss: 0.2890
# Epoch: 1/10... Training loss: 0.2882
# Epoch: 1/10... Training loss: 0.2896
# Epoch: 1/10... Training loss: 0.2890
# Epoch: 1/10... Training loss: 0.2819
# Epoch: 1/10... Training loss: 0.2880
# Epoch: 1/10... Training loss: 0.2795
# Epoch: 1/10... Training loss: 0.2796
# Epoch: 1/10... Training loss: 0.2733
# Epoch: 1/10... Training loss: 0.2786
# Epoch: 1/10... Training loss: 0.2808
# Epoch: 1/10... Training loss: 0.2775
# Epoch: 1/10... Training loss: 0.2717
# Epoch: 1/10... Training loss: 0.2747
# Epoch: 1/10... Training loss: 0.2688
# Epoch: 1/10... Training loss: 0.2728
# Epoch: 1/10... Training loss: 0.2710
# Epoch: 1/10... Training loss: 0.2680
# Epoch: 1/10... Training loss: 0.2638
# Epoch: 1/10... Training loss: 0.2666
# Epoch: 1/10... Training loss: 0.2693
# Epoch: 1/10... Training loss: 0.2690
# Epoch: 1/10... Training loss: 0.2642
# Epoch: 1/10... Training loss: 0.2570
# Epoch: 1/10... Training loss: 0.2573
# Epoch: 1/10... Training loss: 0.2642
# Epoch: 1/10... Training loss: 0.2567
# Epoch: 1/10... Training loss: 0.2617
# Epoch: 1/10... Training loss: 0.2554
# Epoch: 1/10... Training loss: 0.2572
# Epoch: 1/10... Training loss: 0.2577
# Epoch: 1/10... Training loss: 0.2547
# Epoch: 1/10... Training loss: 0.2508
# Epoch: 1/10... Training loss: 0.2553
# Epoch: 1/10... Training loss: 0.2494
# Epoch: 1/10... Training loss: 0.2490
# Epoch: 1/10... Training loss: 0.2562
# Epoch: 1/10... Training loss: 0.2528
# Epoch: 1/10... Training loss: 0.2585
# Epoch: 1/10... Training loss: 0.2527
# Epoch: 1/10... Training loss: 0.2495
# Epoch: 1/10... Training loss: 0.2522
# Epoch: 1/10... Training loss: 0.2499
# Epoch: 1/10... Training loss: 0.2552
# Epoch: 1/10... Training loss: 0.2471
# Epoch: 1/10... Training loss: 0.2491
# Epoch: 1/10... Training loss: 0.2457
# Epoch: 1/10... Training loss: 0.2435
# Epoch: 1/10... Training loss: 0.2444
# Epoch: 1/10... Training loss: 0.2519
# Epoch: 1/10... Training loss: 0.2518
# Epoch: 1/10... Training loss: 0.2460
# Epoch: 1/10... Training loss: 0.2368
# Epoch: 1/10... Training loss: 0.2504
# Epoch: 1/10... Training loss: 0.2336
# Epoch: 1/10... Training loss: 0.2496
# Epoch: 1/10... Training loss: 0.2440
# Epoch: 1/10... Training loss: 0.2444
# Epoch: 1/10... Training loss: 0.2431
# Epoch: 1/10... Training loss: 0.2364
# Epoch: 1/10... Training loss: 0.2364
# Epoch: 1/10... Training loss: 0.2436
# Epoch: 1/10... Training loss: 0.2461
# Epoch: 1/10... Training loss: 0.2491
# Epoch: 1/10... Training loss: 0.2449
# Epoch: 1/10... Training loss: 0.2427
# Epoch: 1/10... Training loss: 0.2360
# Epoch: 1/10... Training loss: 0.2408
# Epoch: 1/10... Training loss: 0.2452
# Epoch: 1/10... Training loss: 0.2320
# Epoch: 1/10... Training loss: 0.2334
# Epoch: 1/10... Training loss: 0.2359
# Epoch: 1/10... Training loss: 0.2414
# Epoch: 1/10... Training loss: 0.2355
# Epoch: 1/10... Training loss: 0.2403
# Epoch: 1/10... Training loss: 0.2403
# Epoch: 1/10... Training loss: 0.2346
# Epoch: 1/10... Training loss: 0.2329
# Epoch: 1/10... Training loss: 0.2329
# Epoch: 1/10... Training loss: 0.2308
# Epoch: 1/10... Training loss: 0.2236
# Epoch: 1/10... Training loss: 0.2274
# Epoch: 1/10... Training loss: 0.2353
# Epoch: 1/10... Training loss: 0.2394
# Epoch: 1/10... Training loss: 0.2221
# Epoch: 1/10... Training loss: 0.2360
# Epoch: 1/10... Training loss: 0.2279
# Epoch: 1/10... Training loss: 0.2315
# Epoch: 1/10... Training loss: 0.2304
# Epoch: 1/10... Training loss: 0.2276
# Epoch: 1/10... Training loss: 0.2347
# Epoch: 1/10... Training loss: 0.2301
# Epoch: 1/10... Training loss: 0.2230
# Epoch: 1/10... Training loss: 0.2261
# Epoch: 1/10... Training loss: 0.2308
# Epoch: 1/10... Training loss: 0.2268
# Epoch: 1/10... Training loss: 0.2318
# Epoch: 1/10... Training loss: 0.2299
# Epoch: 1/10... Training loss: 0.2279
# Epoch: 1/10... Training loss: 0.2275
# Epoch: 1/10... Training loss: 0.2258
# Epoch: 1/10... Training loss: 0.2220
# Epoch: 1/10... Training loss: 0.2235
# Epoch: 1/10... Training loss: 0.2207
# Epoch: 1/10... Training loss: 0.2301
# Epoch: 1/10... Training loss: 0.2271
# Epoch: 1/10... Training loss: 0.2280
# Epoch: 1/10... Training loss: 0.2296
# Epoch: 1/10... Training loss: 0.2257
# Epoch: 1/10... Training loss: 0.2259
# Epoch: 1/10... Training loss: 0.2257
# Epoch: 1/10... Training loss: 0.2188
# Epoch: 1/10... Training loss: 0.2196
# Epoch: 1/10... Training loss: 0.2242
# Epoch: 1/10... Training loss: 0.2196
# Epoch: 1/10... Training loss: 0.2161
# Epoch: 1/10... Training loss: 0.2236
# Epoch: 1/10... Training loss: 0.2197
# Epoch: 1/10... Training loss: 0.2198
# Epoch: 1/10... Training loss: 0.2196
# Epoch: 1/10... Training loss: 0.2205
# Epoch: 1/10... Training loss: 0.2252
# Epoch: 1/10... Training loss: 0.2237
# Epoch: 1/10... Training loss: 0.2296
# Epoch: 1/10... Training loss: 0.2202
# Epoch: 1/10... Training loss: 0.2215
# Epoch: 1/10... Training loss: 0.2137
# Epoch: 1/10... Training loss: 0.2217
# Epoch: 1/10... Training loss: 0.2212
# Epoch: 1/10... Training loss: 0.2224
# Epoch: 1/10... Training loss: 0.2208
# Epoch: 1/10... Training loss: 0.2221
# Epoch: 1/10... Training loss: 0.2200
# Epoch: 1/10... Training loss: 0.2182
# Epoch: 1/10... Training loss: 0.2212
# Epoch: 1/10... Training loss: 0.2170
# Epoch: 1/10... Training loss: 0.2236
# Epoch: 1/10... Training loss: 0.2121
# Epoch: 1/10... Training loss: 0.2134
# Epoch: 1/10... Training loss: 0.2260
# Epoch: 1/10... Training loss: 0.2174
# Epoch: 1/10... Training loss: 0.2124
# Epoch: 1/10... Training loss: 0.2165
# Epoch: 1/10... Training loss: 0.2167
# Epoch: 1/10... Training loss: 0.2125
# Epoch: 1/10... Training loss: 0.2051
# Epoch: 1/10... Training loss: 0.2158
# Epoch: 1/10... Training loss: 0.2138
# Epoch: 1/10... Training loss: 0.2174
# Epoch: 1/10... Training loss: 0.2203
# Epoch: 1/10... Training loss: 0.2091
# Epoch: 1/10... Training loss: 0.2167
# Epoch: 1/10... Training loss: 0.2092
# Epoch: 1/10... Training loss: 0.2189
# Epoch: 1/10... Training loss: 0.2188
# Epoch: 1/10... Training loss: 0.2188
# Epoch: 1/10... Training loss: 0.2151
# Epoch: 1/10... Training loss: 0.2188
# Epoch: 1/10... Training loss: 0.2112
# Epoch: 1/10... Training loss: 0.2122
# Epoch: 1/10... Training loss: 0.2166
# Epoch: 1/10... Training loss: 0.2099
# Epoch: 1/10... Training loss: 0.2095
# Epoch: 1/10... Training loss: 0.2075
# Epoch: 1/10... Training loss: 0.2102
# Epoch: 1/10... Training loss: 0.2111
# Epoch: 1/10... Training loss: 0.2108
# Epoch: 1/10... Training loss: 0.2195
# Epoch: 1/10... Training loss: 0.2167
# Epoch: 1/10... Training loss: 0.2114
# Epoch: 1/10... Training loss: 0.2096
# Epoch: 1/10... Training loss: 0.2076
# Epoch: 1/10... Training loss: 0.2094
# Epoch: 1/10... Training loss: 0.2093
# Epoch: 1/10... Training loss: 0.2078
# Epoch: 1/10... Training loss: 0.2060
# Epoch: 1/10... Training loss: 0.2023
# Epoch: 1/10... Training loss: 0.2062
# Epoch: 1/10... Training loss: 0.2086
# Epoch: 1/10... Training loss: 0.2101
# Epoch: 2/10... Training loss: 0.2083
# Epoch: 2/10... Training loss: 0.2118
# Epoch: 2/10... Training loss: 0.2103
# Epoch: 2/10... Training loss: 0.2037
# Epoch: 2/10... Training loss: 0.2136
# Epoch: 2/10... Training loss: 0.2095
# Epoch: 2/10... Training loss: 0.2032
# Epoch: 2/10... Training loss: 0.2074
# Epoch: 2/10... Training loss: 0.2048
# Epoch: 2/10... Training loss: 0.2058
# Epoch: 2/10... Training loss: 0.2085
# Epoch: 2/10... Training loss: 0.2077
# Epoch: 2/10... Training loss: 0.2062
# Epoch: 2/10... Training loss: 0.2050
# Epoch: 2/10... Training loss: 0.2113
# Epoch: 2/10... Training loss: 0.2076
# Epoch: 2/10... Training loss: 0.2089
# Epoch: 2/10... Training loss: 0.2030
# Epoch: 2/10... Training loss: 0.2095
# Epoch: 2/10... Training loss: 0.2060
# Epoch: 2/10... Training loss: 0.2006
# Epoch: 2/10... Training loss: 0.2061
# Epoch: 2/10... Training loss: 0.2069
# Epoch: 2/10... Training loss: 0.2087
# Epoch: 2/10... Training loss: 0.2031
# Epoch: 2/10... Training loss: 0.2057
# Epoch: 2/10... Training loss: 0.2053
# Epoch: 2/10... Training loss: 0.2087
# Epoch: 2/10... Training loss: 0.2072
# Epoch: 2/10... Training loss: 0.2032
# Epoch: 2/10... Training loss: 0.2035
# Epoch: 2/10... Training loss: 0.2037
# Epoch: 2/10... Training loss: 0.2062
# Epoch: 2/10... Training loss: 0.2047
# Epoch: 2/10... Training loss: 0.1956
# Epoch: 2/10... Training loss: 0.2044
# Epoch: 2/10... Training loss: 0.1996
# Epoch: 2/10... Training loss: 0.2037
# Epoch: 2/10... Training loss: 0.2028
# Epoch: 2/10... Training loss: 0.1988
# Epoch: 2/10... Training loss: 0.2105
# Epoch: 2/10... Training loss: 0.2064
# Epoch: 2/10... Training loss: 0.1956
# Epoch: 2/10... Training loss: 0.2008
# Epoch: 2/10... Training loss: 0.2075
# Epoch: 2/10... Training loss: 0.2031
# Epoch: 2/10... Training loss: 0.1991
# Epoch: 2/10... Training loss: 0.2004
# Epoch: 2/10... Training loss: 0.2007
# Epoch: 2/10... Training loss: 0.1993
# Epoch: 2/10... Training loss: 0.1978
# Epoch: 2/10... Training loss: 0.2046
# Epoch: 2/10... Training loss: 0.1961
# Epoch: 2/10... Training loss: 0.2047
# Epoch: 2/10... Training loss: 0.2024
# Epoch: 2/10... Training loss: 0.1953
# Epoch: 2/10... Training loss: 0.1935
# Epoch: 2/10... Training loss: 0.2004
# Epoch: 2/10... Training loss: 0.1976
# Epoch: 2/10... Training loss: 0.2015
# Epoch: 2/10... Training loss: 0.1944
# Epoch: 2/10... Training loss: 0.1968
# Epoch: 2/10... Training loss: 0.2059
# Epoch: 2/10... Training loss: 0.2006
# Epoch: 2/10... Training loss: 0.1984
# Epoch: 2/10... Training loss: 0.2035
# Epoch: 2/10... Training loss: 0.1995
# Epoch: 2/10... Training loss: 0.1886
# Epoch: 2/10... Training loss: 0.1968
# Epoch: 2/10... Training loss: 0.1904
# Epoch: 2/10... Training loss: 0.1952
# Epoch: 2/10... Training loss: 0.2013
# Epoch: 2/10... Training loss: 0.1963
# Epoch: 2/10... Training loss: 0.1952
# Epoch: 2/10... Training loss: 0.1960
# Epoch: 2/10... Training loss: 0.2001
# Epoch: 2/10... Training loss: 0.2042
# Epoch: 2/10... Training loss: 0.1946
# Epoch: 2/10... Training loss: 0.2013
# Epoch: 2/10... Training loss: 0.2014
# Epoch: 2/10... Training loss: 0.2011
# Epoch: 2/10... Training loss: 0.1942
# Epoch: 2/10... Training loss: 0.2050
# Epoch: 2/10... Training loss: 0.2017
# Epoch: 2/10... Training loss: 0.1938
# Epoch: 2/10... Training loss: 0.1940
# Epoch: 2/10... Training loss: 0.2008
# Epoch: 2/10... Training loss: 0.1980
# Epoch: 2/10... Training loss: 0.1896
# Epoch: 2/10... Training loss: 0.2023
# Epoch: 2/10... Training loss: 0.2014
# Epoch: 2/10... Training loss: 0.2006
# Epoch: 2/10... Training loss: 0.2073
# Epoch: 2/10... Training loss: 0.1975
# Epoch: 2/10... Training loss: 0.1945
# Epoch: 2/10... Training loss: 0.1976
# Epoch: 2/10... Training loss: 0.1973
# Epoch: 2/10... Training loss: 0.2003
# Epoch: 2/10... Training loss: 0.1925
# Epoch: 2/10... Training loss: 0.1954
# Epoch: 2/10... Training loss: 0.1929
# Epoch: 2/10... Training loss: 0.1985
# Epoch: 2/10... Training loss: 0.1923
# Epoch: 2/10... Training loss: 0.1865
# Epoch: 2/10... Training loss: 0.2016
# Epoch: 2/10... Training loss: 0.2010
# Epoch: 2/10... Training loss: 0.1863
# Epoch: 2/10... Training loss: 0.1997
# Epoch: 2/10... Training loss: 0.1980
# Epoch: 2/10... Training loss: 0.1939
# Epoch: 2/10... Training loss: 0.1990
# Epoch: 2/10... Training loss: 0.1929
# Epoch: 2/10... Training loss: 0.2021
# Epoch: 2/10... Training loss: 0.1889
# Epoch: 2/10... Training loss: 0.1959
# Epoch: 2/10... Training loss: 0.1992
# Epoch: 2/10... Training loss: 0.2001
# Epoch: 2/10... Training loss: 0.1932
# Epoch: 2/10... Training loss: 0.1922
# Epoch: 2/10... Training loss: 0.1899
# Epoch: 2/10... Training loss: 0.1997
# Epoch: 2/10... Training loss: 0.1846
# Epoch: 2/10... Training loss: 0.1999
# Epoch: 2/10... Training loss: 0.1950
# Epoch: 2/10... Training loss: 0.1974
# Epoch: 2/10... Training loss: 0.1993
# Epoch: 2/10... Training loss: 0.1976
# Epoch: 2/10... Training loss: 0.1938
# Epoch: 2/10... Training loss: 0.1947
# Epoch: 2/10... Training loss: 0.1954
# Epoch: 2/10... Training loss: 0.1936
# Epoch: 2/10... Training loss: 0.1948
# Epoch: 2/10... Training loss: 0.1944
# Epoch: 2/10... Training loss: 0.1930
# Epoch: 2/10... Training loss: 0.1916
# Epoch: 2/10... Training loss: 0.1872
# Epoch: 2/10... Training loss: 0.1915
# Epoch: 2/10... Training loss: 0.1964
# Epoch: 2/10... Training loss: 0.1900
# Epoch: 2/10... Training loss: 0.1956
# Epoch: 2/10... Training loss: 0.1923
# Epoch: 2/10... Training loss: 0.1948
# Epoch: 2/10... Training loss: 0.1991
# Epoch: 2/10... Training loss: 0.1911
# Epoch: 2/10... Training loss: 0.1941
# Epoch: 2/10... Training loss: 0.1938
# Epoch: 2/10... Training loss: 0.1940
# Epoch: 2/10... Training loss: 0.1945
# Epoch: 2/10... Training loss: 0.1920
# Epoch: 2/10... Training loss: 0.1876
# Epoch: 2/10... Training loss: 0.1935
# Epoch: 2/10... Training loss: 0.1922
# Epoch: 2/10... Training loss: 0.1891
# Epoch: 2/10... Training loss: 0.1925
# Epoch: 2/10... Training loss: 0.1975
# Epoch: 2/10... Training loss: 0.1925
# Epoch: 2/10... Training loss: 0.1928
# Epoch: 2/10... Training loss: 0.1974
# Epoch: 2/10... Training loss: 0.1917
# Epoch: 2/10... Training loss: 0.1958
# Epoch: 2/10... Training loss: 0.1891
# Epoch: 2/10... Training loss: 0.1880
# Epoch: 2/10... Training loss: 0.1968
# Epoch: 2/10... Training loss: 0.1900
# Epoch: 2/10... Training loss: 0.1905
# Epoch: 2/10... Training loss: 0.1866
# Epoch: 2/10... Training loss: 0.1996
# Epoch: 2/10... Training loss: 0.1956
# Epoch: 2/10... Training loss: 0.1909
# Epoch: 2/10... Training loss: 0.1967
# Epoch: 2/10... Training loss: 0.1879
# Epoch: 2/10... Training loss: 0.1986
# Epoch: 2/10... Training loss: 0.1942
# Epoch: 2/10... Training loss: 0.1962
# Epoch: 2/10... Training loss: 0.1899
# Epoch: 2/10... Training loss: 0.1866
# Epoch: 2/10... Training loss: 0.1936
# Epoch: 2/10... Training loss: 0.1895
# Epoch: 2/10... Training loss: 0.1923
# Epoch: 2/10... Training loss: 0.1922
# Epoch: 2/10... Training loss: 0.1903
# Epoch: 2/10... Training loss: 0.1862
# Epoch: 2/10... Training loss: 0.1904
# Epoch: 2/10... Training loss: 0.1953
# Epoch: 2/10... Training loss: 0.1975
# Epoch: 2/10... Training loss: 0.1893
# Epoch: 2/10... Training loss: 0.1871
# Epoch: 2/10... Training loss: 0.1831
# Epoch: 2/10... Training loss: 0.1875
# Epoch: 2/10... Training loss: 0.1894
# Epoch: 2/10... Training loss: 0.1887
# Epoch: 2/10... Training loss: 0.1880
# Epoch: 2/10... Training loss: 0.1905
# Epoch: 2/10... Training loss: 0.1868
# Epoch: 2/10... Training loss: 0.1891
# Epoch: 2/10... Training loss: 0.1862
# Epoch: 2/10... Training loss: 0.1961
# Epoch: 2/10... Training loss: 0.1901
# Epoch: 2/10... Training loss: 0.1869
# Epoch: 2/10... Training loss: 0.1935
# Epoch: 2/10... Training loss: 0.1871
# Epoch: 2/10... Training loss: 0.1897
# Epoch: 2/10... Training loss: 0.1969
# Epoch: 2/10... Training loss: 0.1867
# Epoch: 2/10... Training loss: 0.1884
# Epoch: 2/10... Training loss: 0.1907
# Epoch: 2/10... Training loss: 0.1942
# Epoch: 2/10... Training loss: 0.1859
# Epoch: 2/10... Training loss: 0.1905
# Epoch: 2/10... Training loss: 0.1858
# Epoch: 2/10... Training loss: 0.1884
# Epoch: 2/10... Training loss: 0.1880
# Epoch: 2/10... Training loss: 0.1901
# Epoch: 2/10... Training loss: 0.1868
# Epoch: 2/10... Training loss: 0.1863
# Epoch: 2/10... Training loss: 0.1860
# Epoch: 2/10... Training loss: 0.1898
# Epoch: 2/10... Training loss: 0.1900
# Epoch: 2/10... Training loss: 0.1958
# Epoch: 2/10... Training loss: 0.1872
# Epoch: 2/10... Training loss: 0.1947
# Epoch: 2/10... Training loss: 0.1833
# Epoch: 2/10... Training loss: 0.1830
# Epoch: 2/10... Training loss: 0.1865
# Epoch: 2/10... Training loss: 0.1908
# Epoch: 2/10... Training loss: 0.1916
# Epoch: 2/10... Training loss: 0.1892
# Epoch: 2/10... Training loss: 0.1850
# Epoch: 2/10... Training loss: 0.1826
# Epoch: 2/10... Training loss: 0.1849
# Epoch: 2/10... Training loss: 0.1838
# Epoch: 2/10... Training loss: 0.1857
# Epoch: 2/10... Training loss: 0.1822
# Epoch: 2/10... Training loss: 0.1846
# Epoch: 2/10... Training loss: 0.1916
# Epoch: 2/10... Training loss: 0.1832
# Epoch: 2/10... Training loss: 0.1837
# Epoch: 2/10... Training loss: 0.1880
# Epoch: 2/10... Training loss: 0.1933
# Epoch: 2/10... Training loss: 0.1879
# Epoch: 2/10... Training loss: 0.1830
# Epoch: 2/10... Training loss: 0.1875
# Epoch: 2/10... Training loss: 0.1852
# Epoch: 2/10... Training loss: 0.1787
# Epoch: 2/10... Training loss: 0.1875
# Epoch: 2/10... Training loss: 0.1798
# Epoch: 2/10... Training loss: 0.1839
# Epoch: 2/10... Training loss: 0.1877
# Epoch: 2/10... Training loss: 0.1867
# Epoch: 2/10... Training loss: 0.1789
# Epoch: 2/10... Training loss: 0.1863
# Epoch: 2/10... Training loss: 0.1838
# Epoch: 2/10... Training loss: 0.1929
# Epoch: 2/10... Training loss: 0.1883
# Epoch: 2/10... Training loss: 0.1789
# Epoch: 2/10... Training loss: 0.1826
# Epoch: 2/10... Training loss: 0.1908
# Epoch: 2/10... Training loss: 0.1864
# Epoch: 2/10... Training loss: 0.1825
# Epoch: 2/10... Training loss: 0.1989
# Epoch: 2/10... Training loss: 0.1795
# Epoch: 2/10... Training loss: 0.1860
# Epoch: 2/10... Training loss: 0.1905
# Epoch: 2/10... Training loss: 0.1879
# Epoch: 2/10... Training loss: 0.1860
# Epoch: 2/10... Training loss: 0.1838
# Epoch: 2/10... Training loss: 0.1884
# Epoch: 2/10... Training loss: 0.1795
# Epoch: 2/10... Training loss: 0.1832
# Epoch: 2/10... Training loss: 0.1805
# Epoch: 2/10... Training loss: 0.1895
# Epoch: 2/10... Training loss: 0.1878
# Epoch: 2/10... Training loss: 0.1851
# Epoch: 2/10... Training loss: 0.1878
# Epoch: 2/10... Training loss: 0.1868
# Epoch: 2/10... Training loss: 0.1788
# Epoch: 2/10... Training loss: 0.1901
# Epoch: 2/10... Training loss: 0.1856
# Epoch: 2/10... Training loss: 0.1836
# Epoch: 2/10... Training loss: 0.1857
# Epoch: 2/10... Training loss: 0.1800
# Epoch: 2/10... Training loss: 0.1916
# Epoch: 2/10... Training loss: 0.1932
# Epoch: 2/10... Training loss: 0.1913
# Epoch: 2/10... Training loss: 0.1873
# Epoch: 2/10... Training loss: 0.1840
# Epoch: 2/10... Training loss: 0.1844
# Epoch: 2/10... Training loss: 0.1842
# Epoch: 2/10... Training loss: 0.1852
# Epoch: 2/10... Training loss: 0.1853
# Epoch: 2/10... Training loss: 0.1818
# Epoch: 2/10... Training loss: 0.1837
# Epoch: 2/10... Training loss: 0.1898
# Epoch: 2/10... Training loss: 0.1835
# Epoch: 2/10... Training loss: 0.1901
# Epoch: 2/10... Training loss: 0.1794
# Epoch: 2/10... Training loss: 0.1891
# Epoch: 2/10... Training loss: 0.1854
# Epoch: 2/10... Training loss: 0.1777
# Epoch: 2/10... Training loss: 0.1811
# Epoch: 3/10... Training loss: 0.1832
# Epoch: 3/10... Training loss: 0.1848
# Epoch: 3/10... Training loss: 0.1854
# Epoch: 3/10... Training loss: 0.1832
# Epoch: 3/10... Training loss: 0.1879
# Epoch: 3/10... Training loss: 0.1818
# Epoch: 3/10... Training loss: 0.1831
# Epoch: 3/10... Training loss: 0.1812
# Epoch: 3/10... Training loss: 0.1798
# Epoch: 3/10... Training loss: 0.1856
# Epoch: 3/10... Training loss: 0.1780
# Epoch: 3/10... Training loss: 0.1836
# Epoch: 3/10... Training loss: 0.1838
# Epoch: 3/10... Training loss: 0.1855
# Epoch: 3/10... Training loss: 0.1778
# Epoch: 3/10... Training loss: 0.1879
# Epoch: 3/10... Training loss: 0.1764
# Epoch: 3/10... Training loss: 0.1818
# Epoch: 3/10... Training loss: 0.1893
# Epoch: 3/10... Training loss: 0.1832
# Epoch: 3/10... Training loss: 0.1861
# Epoch: 3/10... Training loss: 0.1841
# Epoch: 3/10... Training loss: 0.1880
# Epoch: 3/10... Training loss: 0.1808
# Epoch: 3/10... Training loss: 0.1855
# Epoch: 3/10... Training loss: 0.1861
# Epoch: 3/10... Training loss: 0.1812
# Epoch: 3/10... Training loss: 0.1805
# Epoch: 3/10... Training loss: 0.1863
# Epoch: 3/10... Training loss: 0.1839
# Epoch: 3/10... Training loss: 0.1778
# Epoch: 3/10... Training loss: 0.1787
# Epoch: 3/10... Training loss: 0.1815
# Epoch: 3/10... Training loss: 0.1796
# Epoch: 3/10... Training loss: 0.1789
# Epoch: 3/10... Training loss: 0.1812
# Epoch: 3/10... Training loss: 0.1781
# Epoch: 3/10... Training loss: 0.1826
# Epoch: 3/10... Training loss: 0.1818
# Epoch: 3/10... Training loss: 0.1846
# Epoch: 3/10... Training loss: 0.1769
# Epoch: 3/10... Training loss: 0.1803
# Epoch: 3/10... Training loss: 0.1798
# Epoch: 3/10... Training loss: 0.1900
# Epoch: 3/10... Training loss: 0.1761
# Epoch: 3/10... Training loss: 0.1857
# Epoch: 3/10... Training loss: 0.1824
# Epoch: 3/10... Training loss: 0.1813
# Epoch: 3/10... Training loss: 0.1889
# Epoch: 3/10... Training loss: 0.1842
# Epoch: 3/10... Training loss: 0.1764
# Epoch: 3/10... Training loss: 0.1824
# Epoch: 3/10... Training loss: 0.1773
# Epoch: 3/10... Training loss: 0.1758
# Epoch: 3/10... Training loss: 0.1765
# Epoch: 3/10... Training loss: 0.1802
# Epoch: 3/10... Training loss: 0.1744
# Epoch: 3/10... Training loss: 0.1866
# Epoch: 3/10... Training loss: 0.1825
# Epoch: 3/10... Training loss: 0.1778
# Epoch: 3/10... Training loss: 0.1797
# Epoch: 3/10... Training loss: 0.1788
# Epoch: 3/10... Training loss: 0.1840
# Epoch: 3/10... Training loss: 0.1826
# Epoch: 3/10... Training loss: 0.1759
# Epoch: 3/10... Training loss: 0.1803
# Epoch: 3/10... Training loss: 0.1778
# Epoch: 3/10... Training loss: 0.1735
# Epoch: 3/10... Training loss: 0.1787
# Epoch: 3/10... Training loss: 0.1808
# Epoch: 3/10... Training loss: 0.1739
# Epoch: 3/10... Training loss: 0.1860
# Epoch: 3/10... Training loss: 0.1815
# Epoch: 3/10... Training loss: 0.1811
# Epoch: 3/10... Training loss: 0.1755
# Epoch: 3/10... Training loss: 0.1821
# Epoch: 3/10... Training loss: 0.1854
# Epoch: 3/10... Training loss: 0.1794
# Epoch: 3/10... Training loss: 0.1803
# Epoch: 3/10... Training loss: 0.1765
# Epoch: 3/10... Training loss: 0.1837
# Epoch: 3/10... Training loss: 0.1721
# Epoch: 3/10... Training loss: 0.1782
# Epoch: 3/10... Training loss: 0.1785
# Epoch: 3/10... Training loss: 0.1817
# Epoch: 3/10... Training loss: 0.1770
# Epoch: 3/10... Training loss: 0.1863
# Epoch: 3/10... Training loss: 0.1828
# Epoch: 3/10... Training loss: 0.1781
# Epoch: 3/10... Training loss: 0.1840
# Epoch: 3/10... Training loss: 0.1783
# Epoch: 3/10... Training loss: 0.1808
# Epoch: 3/10... Training loss: 0.1753
# Epoch: 3/10... Training loss: 0.1784
# Epoch: 3/10... Training loss: 0.1774
# Epoch: 3/10... Training loss: 0.1758
# Epoch: 3/10... Training loss: 0.1800
# Epoch: 3/10... Training loss: 0.1800
# Epoch: 3/10... Training loss: 0.1792
# Epoch: 3/10... Training loss: 0.1820
# Epoch: 3/10... Training loss: 0.1779
# Epoch: 3/10... Training loss: 0.1781
# Epoch: 3/10... Training loss: 0.1821
# Epoch: 3/10... Training loss: 0.1710
# Epoch: 3/10... Training loss: 0.1755
# Epoch: 3/10... Training loss: 0.1766
# Epoch: 3/10... Training loss: 0.1802
# Epoch: 3/10... Training loss: 0.1763
# Epoch: 3/10... Training loss: 0.1788
# Epoch: 3/10... Training loss: 0.1775
# Epoch: 3/10... Training loss: 0.1769
# Epoch: 3/10... Training loss: 0.1788
# Epoch: 3/10... Training loss: 0.1763
# Epoch: 3/10... Training loss: 0.1789
# Epoch: 3/10... Training loss: 0.1713
# Epoch: 3/10... Training loss: 0.1714
# Epoch: 3/10... Training loss: 0.1742
# Epoch: 3/10... Training loss: 0.1727
# Epoch: 3/10... Training loss: 0.1744
# Epoch: 3/10... Training loss: 0.1781
# Epoch: 3/10... Training loss: 0.1832
# Epoch: 3/10... Training loss: 0.1766
# Epoch: 3/10... Training loss: 0.1764
# Epoch: 3/10... Training loss: 0.1787
# Epoch: 3/10... Training loss: 0.1748
# Epoch: 3/10... Training loss: 0.1810
# Epoch: 3/10... Training loss: 0.1794
# Epoch: 3/10... Training loss: 0.1754
# Epoch: 3/10... Training loss: 0.1766
# Epoch: 3/10... Training loss: 0.1858
# Epoch: 3/10... Training loss: 0.1785
# Epoch: 3/10... Training loss: 0.1735
# Epoch: 3/10... Training loss: 0.1787
# Epoch: 3/10... Training loss: 0.1745
# Epoch: 3/10... Training loss: 0.1779
# Epoch: 3/10... Training loss: 0.1787
# Epoch: 3/10... Training loss: 0.1764
# Epoch: 3/10... Training loss: 0.1724
# Epoch: 3/10... Training loss: 0.1816
# Epoch: 3/10... Training loss: 0.1790
# Epoch: 3/10... Training loss: 0.1742
# Epoch: 3/10... Training loss: 0.1766
# Epoch: 3/10... Training loss: 0.1734
# Epoch: 3/10... Training loss: 0.1745
# Epoch: 3/10... Training loss: 0.1742
# Epoch: 3/10... Training loss: 0.1759
# Epoch: 3/10... Training loss: 0.1768
# Epoch: 3/10... Training loss: 0.1802
# Epoch: 3/10... Training loss: 0.1787
# Epoch: 3/10... Training loss: 0.1740
# Epoch: 3/10... Training loss: 0.1787
# Epoch: 3/10... Training loss: 0.1762
# Epoch: 3/10... Training loss: 0.1751
# Epoch: 3/10... Training loss: 0.1697
# Epoch: 3/10... Training loss: 0.1790
# Epoch: 3/10... Training loss: 0.1785
# Epoch: 3/10... Training loss: 0.1727
# Epoch: 3/10... Training loss: 0.1731
# Epoch: 3/10... Training loss: 0.1833
# Epoch: 3/10... Training loss: 0.1812
# Epoch: 3/10... Training loss: 0.1764
# Epoch: 3/10... Training loss: 0.1743
# Epoch: 3/10... Training loss: 0.1795
# Epoch: 3/10... Training loss: 0.1767
# Epoch: 3/10... Training loss: 0.1779
# Epoch: 3/10... Training loss: 0.1750
# Epoch: 3/10... Training loss: 0.1697
# Epoch: 3/10... Training loss: 0.1764
# Epoch: 3/10... Training loss: 0.1772
# Epoch: 3/10... Training loss: 0.1808
# Epoch: 3/10... Training loss: 0.1760
# Epoch: 3/10... Training loss: 0.1742
# Epoch: 3/10... Training loss: 0.1780
# Epoch: 3/10... Training loss: 0.1712
# Epoch: 3/10... Training loss: 0.1781
# Epoch: 3/10... Training loss: 0.1809
# Epoch: 3/10... Training loss: 0.1692
# Epoch: 3/10... Training loss: 0.1742
# Epoch: 3/10... Training loss: 0.1731
# Epoch: 3/10... Training loss: 0.1758
# Epoch: 3/10... Training loss: 0.1717
# Epoch: 3/10... Training loss: 0.1747
# Epoch: 3/10... Training loss: 0.1725
# Epoch: 3/10... Training loss: 0.1769
# Epoch: 3/10... Training loss: 0.1733
# Epoch: 3/10... Training loss: 0.1759
# Epoch: 3/10... Training loss: 0.1762
# Epoch: 3/10... Training loss: 0.1652
# Epoch: 3/10... Training loss: 0.1712
# Epoch: 3/10... Training loss: 0.1708
# Epoch: 3/10... Training loss: 0.1760
# Epoch: 3/10... Training loss: 0.1756
# Epoch: 3/10... Training loss: 0.1753
# Epoch: 3/10... Training loss: 0.1767
# Epoch: 3/10... Training loss: 0.1729
# Epoch: 3/10... Training loss: 0.1819
# Epoch: 3/10... Training loss: 0.1811
# Epoch: 3/10... Training loss: 0.1731
# Epoch: 3/10... Training loss: 0.1730
# Epoch: 3/10... Training loss: 0.1729
# Epoch: 3/10... Training loss: 0.1730
# Epoch: 3/10... Training loss: 0.1787
# Epoch: 3/10... Training loss: 0.1711
# Epoch: 3/10... Training loss: 0.1705
# Epoch: 3/10... Training loss: 0.1784
# Epoch: 3/10... Training loss: 0.1698
# Epoch: 3/10... Training loss: 0.1703
# Epoch: 3/10... Training loss: 0.1780
# Epoch: 3/10... Training loss: 0.1750
# Epoch: 3/10... Training loss: 0.1698
# Epoch: 3/10... Training loss: 0.1704
# Epoch: 3/10... Training loss: 0.1757
# Epoch: 3/10... Training loss: 0.1781
# Epoch: 3/10... Training loss: 0.1712
# Epoch: 3/10... Training loss: 0.1738
# Epoch: 3/10... Training loss: 0.1815
# Epoch: 3/10... Training loss: 0.1775
# Epoch: 3/10... Training loss: 0.1694
# Epoch: 3/10... Training loss: 0.1680
# Epoch: 3/10... Training loss: 0.1662
# Epoch: 3/10... Training loss: 0.1709
# Epoch: 3/10... Training loss: 0.1721
# Epoch: 3/10... Training loss: 0.1698
# Epoch: 3/10... Training loss: 0.1769
# Epoch: 3/10... Training loss: 0.1753
# Epoch: 3/10... Training loss: 0.1724
# Epoch: 3/10... Training loss: 0.1689
# Epoch: 3/10... Training loss: 0.1775
# Epoch: 3/10... Training loss: 0.1704
# Epoch: 3/10... Training loss: 0.1700
# Epoch: 3/10... Training loss: 0.1753
# Epoch: 3/10... Training loss: 0.1707
# Epoch: 3/10... Training loss: 0.1749
# Epoch: 3/10... Training loss: 0.1743
# Epoch: 3/10... Training loss: 0.1717
# Epoch: 3/10... Training loss: 0.1733
# Epoch: 3/10... Training loss: 0.1790
# Epoch: 3/10... Training loss: 0.1717
# Epoch: 3/10... Training loss: 0.1743
# Epoch: 3/10... Training loss: 0.1736
# Epoch: 3/10... Training loss: 0.1765
# Epoch: 3/10... Training loss: 0.1746
# Epoch: 3/10... Training loss: 0.1730
# Epoch: 3/10... Training loss: 0.1734
# Epoch: 3/10... Training loss: 0.1762
# Epoch: 3/10... Training loss: 0.1769
# Epoch: 3/10... Training loss: 0.1682
# Epoch: 3/10... Training loss: 0.1728
# Epoch: 3/10... Training loss: 0.1683
# Epoch: 3/10... Training loss: 0.1770
# Epoch: 3/10... Training loss: 0.1733
# Epoch: 3/10... Training loss: 0.1707
# Epoch: 3/10... Training loss: 0.1696
# Epoch: 3/10... Training loss: 0.1741
# Epoch: 3/10... Training loss: 0.1690
# Epoch: 3/10... Training loss: 0.1748
# Epoch: 3/10... Training loss: 0.1769
# Epoch: 3/10... Training loss: 0.1681
# Epoch: 3/10... Training loss: 0.1729
# Epoch: 3/10... Training loss: 0.1751
# Epoch: 3/10... Training loss: 0.1697
# Epoch: 3/10... Training loss: 0.1713
# Epoch: 3/10... Training loss: 0.1703
# Epoch: 3/10... Training loss: 0.1692
# Epoch: 3/10... Training loss: 0.1681
# Epoch: 3/10... Training loss: 0.1633
# Epoch: 3/10... Training loss: 0.1734
# Epoch: 3/10... Training loss: 0.1702
# Epoch: 3/10... Training loss: 0.1768
# Epoch: 3/10... Training loss: 0.1682
# Epoch: 3/10... Training loss: 0.1683
# Epoch: 3/10... Training loss: 0.1752
# Epoch: 3/10... Training loss: 0.1682
# Epoch: 3/10... Training loss: 0.1692
# Epoch: 3/10... Training loss: 0.1689
# Epoch: 3/10... Training loss: 0.1669
# Epoch: 3/10... Training loss: 0.1722
# Epoch: 3/10... Training loss: 0.1678
# Epoch: 3/10... Training loss: 0.1710
# Epoch: 3/10... Training loss: 0.1680
# Epoch: 3/10... Training loss: 0.1655
# Epoch: 3/10... Training loss: 0.1727
# Epoch: 3/10... Training loss: 0.1697
# Epoch: 3/10... Training loss: 0.1772
# Epoch: 3/10... Training loss: 0.1663
# Epoch: 3/10... Training loss: 0.1745
# Epoch: 3/10... Training loss: 0.1713
# Epoch: 3/10... Training loss: 0.1751
# Epoch: 3/10... Training loss: 0.1771
# Epoch: 3/10... Training loss: 0.1744
# Epoch: 3/10... Training loss: 0.1706
# Epoch: 3/10... Training loss: 0.1755
# Epoch: 3/10... Training loss: 0.1749
# Epoch: 3/10... Training loss: 0.1742
# Epoch: 3/10... Training loss: 0.1673
# Epoch: 3/10... Training loss: 0.1631
# Epoch: 3/10... Training loss: 0.1728
# Epoch: 3/10... Training loss: 0.1727
# Epoch: 3/10... Training loss: 0.1749
# Epoch: 3/10... Training loss: 0.1755
# Epoch: 4/10... Training loss: 0.1724
# Epoch: 4/10... Training loss: 0.1677
# Epoch: 4/10... Training loss: 0.1668
# Epoch: 4/10... Training loss: 0.1700
# Epoch: 4/10... Training loss: 0.1718
# Epoch: 4/10... Training loss: 0.1689
# Epoch: 4/10... Training loss: 0.1647
# Epoch: 4/10... Training loss: 0.1770
# Epoch: 4/10... Training loss: 0.1694
# Epoch: 4/10... Training loss: 0.1682
# Epoch: 4/10... Training loss: 0.1648
# Epoch: 4/10... Training loss: 0.1697
# Epoch: 4/10... Training loss: 0.1716
# Epoch: 4/10... Training loss: 0.1677
# Epoch: 4/10... Training loss: 0.1685
# Epoch: 4/10... Training loss: 0.1678
# Epoch: 4/10... Training loss: 0.1700
# Epoch: 4/10... Training loss: 0.1729
# Epoch: 4/10... Training loss: 0.1755
# Epoch: 4/10... Training loss: 0.1683
# Epoch: 4/10... Training loss: 0.1727
# Epoch: 4/10... Training loss: 0.1732
# Epoch: 4/10... Training loss: 0.1719
# Epoch: 4/10... Training loss: 0.1704
# Epoch: 4/10... Training loss: 0.1749
# Epoch: 4/10... Training loss: 0.1728
# Epoch: 4/10... Training loss: 0.1713
# Epoch: 4/10... Training loss: 0.1676
# Epoch: 4/10... Training loss: 0.1694
# Epoch: 4/10... Training loss: 0.1694
# Epoch: 4/10... Training loss: 0.1686
# Epoch: 4/10... Training loss: 0.1691
# Epoch: 4/10... Training loss: 0.1633
# Epoch: 4/10... Training loss: 0.1734
# Epoch: 4/10... Training loss: 0.1681
# Epoch: 4/10... Training loss: 0.1674
# Epoch: 4/10... Training loss: 0.1665
# Epoch: 4/10... Training loss: 0.1656
# Epoch: 4/10... Training loss: 0.1699
# Epoch: 4/10... Training loss: 0.1652
# Epoch: 4/10... Training loss: 0.1690
# Epoch: 4/10... Training loss: 0.1661
# Epoch: 4/10... Training loss: 0.1690
# Epoch: 4/10... Training loss: 0.1674
# Epoch: 4/10... Training loss: 0.1704
# Epoch: 4/10... Training loss: 0.1740
# Epoch: 4/10... Training loss: 0.1748
# Epoch: 4/10... Training loss: 0.1717
# Epoch: 4/10... Training loss: 0.1671
# Epoch: 4/10... Training loss: 0.1691
# Epoch: 4/10... Training loss: 0.1725
# Epoch: 4/10... Training loss: 0.1654
# Epoch: 4/10... Training loss: 0.1694
# Epoch: 4/10... Training loss: 0.1717
# Epoch: 4/10... Training loss: 0.1618
# Epoch: 4/10... Training loss: 0.1693
# Epoch: 4/10... Training loss: 0.1684
# Epoch: 4/10... Training loss: 0.1681
# Epoch: 4/10... Training loss: 0.1708
# Epoch: 4/10... Training loss: 0.1697
# Epoch: 4/10... Training loss: 0.1654
# Epoch: 4/10... Training loss: 0.1660
# Epoch: 4/10... Training loss: 0.1626
# Epoch: 4/10... Training loss: 0.1670
# Epoch: 4/10... Training loss: 0.1707
# Epoch: 4/10... Training loss: 0.1684
# Epoch: 4/10... Training loss: 0.1680
# Epoch: 4/10... Training loss: 0.1666
# Epoch: 4/10... Training loss: 0.1674
# Epoch: 4/10... Training loss: 0.1654
# Epoch: 4/10... Training loss: 0.1687
# Epoch: 4/10... Training loss: 0.1643
# Epoch: 4/10... Training loss: 0.1655
# Epoch: 4/10... Training loss: 0.1695
# Epoch: 4/10... Training loss: 0.1724
# Epoch: 4/10... Training loss: 0.1631
# Epoch: 4/10... Training loss: 0.1690
# Epoch: 4/10... Training loss: 0.1649
# Epoch: 4/10... Training loss: 0.1630
# Epoch: 4/10... Training loss: 0.1670
# Epoch: 4/10... Training loss: 0.1663
# Epoch: 4/10... Training loss: 0.1602
# Epoch: 4/10... Training loss: 0.1663
# Epoch: 4/10... Training loss: 0.1720
# Epoch: 4/10... Training loss: 0.1673
# Epoch: 4/10... Training loss: 0.1664
# Epoch: 4/10... Training loss: 0.1685
# Epoch: 4/10... Training loss: 0.1690
# Epoch: 4/10... Training loss: 0.1686
# Epoch: 4/10... Training loss: 0.1589
# Epoch: 4/10... Training loss: 0.1686
# Epoch: 4/10... Training loss: 0.1662
# Epoch: 4/10... Training loss: 0.1666
# Epoch: 4/10... Training loss: 0.1697
# Epoch: 4/10... Training loss: 0.1678
# Epoch: 4/10... Training loss: 0.1756
# Epoch: 4/10... Training loss: 0.1633
# Epoch: 4/10... Training loss: 0.1652
# Epoch: 4/10... Training loss: 0.1640
# Epoch: 4/10... Training loss: 0.1673
# Epoch: 4/10... Training loss: 0.1718
# Epoch: 4/10... Training loss: 0.1694
# Epoch: 4/10... Training loss: 0.1697
# Epoch: 4/10... Training loss: 0.1692
# Epoch: 4/10... Training loss: 0.1663
# Epoch: 4/10... Training loss: 0.1688
# Epoch: 4/10... Training loss: 0.1677
# Epoch: 4/10... Training loss: 0.1625
# Epoch: 4/10... Training loss: 0.1687
# Epoch: 4/10... Training loss: 0.1678
# Epoch: 4/10... Training loss: 0.1616
# Epoch: 4/10... Training loss: 0.1735
# Epoch: 4/10... Training loss: 0.1648
# Epoch: 4/10... Training loss: 0.1630
# Epoch: 4/10... Training loss: 0.1711
# Epoch: 4/10... Training loss: 0.1643
# Epoch: 4/10... Training loss: 0.1708
# Epoch: 4/10... Training loss: 0.1700
# Epoch: 4/10... Training loss: 0.1685
# Epoch: 4/10... Training loss: 0.1568
# Epoch: 4/10... Training loss: 0.1604
# Epoch: 4/10... Training loss: 0.1637
# Epoch: 4/10... Training loss: 0.1641
# Epoch: 4/10... Training loss: 0.1676
# Epoch: 4/10... Training loss: 0.1643
# Epoch: 4/10... Training loss: 0.1686
# Epoch: 4/10... Training loss: 0.1629
# Epoch: 4/10... Training loss: 0.1676
# Epoch: 4/10... Training loss: 0.1638
# Epoch: 4/10... Training loss: 0.1664
# Epoch: 4/10... Training loss: 0.1644
# Epoch: 4/10... Training loss: 0.1737
# Epoch: 4/10... Training loss: 0.1693
# Epoch: 4/10... Training loss: 0.1633
# Epoch: 4/10... Training loss: 0.1705
# Epoch: 4/10... Training loss: 0.1606
# Epoch: 4/10... Training loss: 0.1630
# Epoch: 4/10... Training loss: 0.1671
# Epoch: 4/10... Training loss: 0.1698
# Epoch: 4/10... Training loss: 0.1707
# Epoch: 4/10... Training loss: 0.1603
# Epoch: 4/10... Training loss: 0.1690
# Epoch: 4/10... Training loss: 0.1723
# Epoch: 4/10... Training loss: 0.1664
# Epoch: 4/10... Training loss: 0.1710
# Epoch: 4/10... Training loss: 0.1696
# Epoch: 4/10... Training loss: 0.1652
# Epoch: 4/10... Training loss: 0.1635
# Epoch: 4/10... Training loss: 0.1660
# Epoch: 4/10... Training loss: 0.1726
# Epoch: 4/10... Training loss: 0.1653
# Epoch: 4/10... Training loss: 0.1677
# Epoch: 4/10... Training loss: 0.1598
# Epoch: 4/10... Training loss: 0.1702
# Epoch: 4/10... Training loss: 0.1675
# Epoch: 4/10... Training loss: 0.1693
# Epoch: 4/10... Training loss: 0.1696
# Epoch: 4/10... Training loss: 0.1663
# Epoch: 4/10... Training loss: 0.1597
# Epoch: 4/10... Training loss: 0.1658
# Epoch: 4/10... Training loss: 0.1691
# Epoch: 4/10... Training loss: 0.1649
# Epoch: 4/10... Training loss: 0.1685
# Epoch: 4/10... Training loss: 0.1710
# Epoch: 4/10... Training loss: 0.1647
# Epoch: 4/10... Training loss: 0.1697
# Epoch: 4/10... Training loss: 0.1669
# Epoch: 4/10... Training loss: 0.1604
# Epoch: 4/10... Training loss: 0.1631
# Epoch: 4/10... Training loss: 0.1606
# Epoch: 4/10... Training loss: 0.1650
# Epoch: 4/10... Training loss: 0.1610
# Epoch: 4/10... Training loss: 0.1626
# Epoch: 4/10... Training loss: 0.1633
# Epoch: 4/10... Training loss: 0.1580
# Epoch: 4/10... Training loss: 0.1705
# Epoch: 4/10... Training loss: 0.1648
# Epoch: 4/10... Training loss: 0.1660
# Epoch: 4/10... Training loss: 0.1676
# Epoch: 4/10... Training loss: 0.1676
# Epoch: 4/10... Training loss: 0.1651
# Epoch: 4/10... Training loss: 0.1662
# Epoch: 4/10... Training loss: 0.1638
# Epoch: 4/10... Training loss: 0.1683
# Epoch: 4/10... Training loss: 0.1673
# Epoch: 4/10... Training loss: 0.1643
# Epoch: 4/10... Training loss: 0.1597
# Epoch: 4/10... Training loss: 0.1622
# Epoch: 4/10... Training loss: 0.1657
# Epoch: 4/10... Training loss: 0.1639
# Epoch: 4/10... Training loss: 0.1672
# Epoch: 4/10... Training loss: 0.1608
# Epoch: 4/10... Training loss: 0.1654
# Epoch: 4/10... Training loss: 0.1605
# Epoch: 4/10... Training loss: 0.1629
# Epoch: 4/10... Training loss: 0.1603
# Epoch: 4/10... Training loss: 0.1566
# Epoch: 4/10... Training loss: 0.1612
# Epoch: 4/10... Training loss: 0.1647
# Epoch: 4/10... Training loss: 0.1690
# Epoch: 4/10... Training loss: 0.1586
# Epoch: 4/10... Training loss: 0.1575
# Epoch: 4/10... Training loss: 0.1618
# Epoch: 4/10... Training loss: 0.1597
# Epoch: 4/10... Training loss: 0.1599
# Epoch: 4/10... Training loss: 0.1608
# Epoch: 4/10... Training loss: 0.1667
# Epoch: 4/10... Training loss: 0.1655
# Epoch: 4/10... Training loss: 0.1697
# Epoch: 4/10... Training loss: 0.1671
# Epoch: 4/10... Training loss: 0.1615
# Epoch: 4/10... Training loss: 0.1598
# Epoch: 4/10... Training loss: 0.1620
# Epoch: 4/10... Training loss: 0.1638
# Epoch: 4/10... Training loss: 0.1624
# Epoch: 4/10... Training loss: 0.1652
# Epoch: 4/10... Training loss: 0.1642
# Epoch: 4/10... Training loss: 0.1685
# Epoch: 4/10... Training loss: 0.1610
# Epoch: 4/10... Training loss: 0.1606
# Epoch: 4/10... Training loss: 0.1661
# Epoch: 4/10... Training loss: 0.1632
# Epoch: 4/10... Training loss: 0.1625
# Epoch: 4/10... Training loss: 0.1674
# Epoch: 4/10... Training loss: 0.1582
# Epoch: 4/10... Training loss: 0.1642
# Epoch: 4/10... Training loss: 0.1596
# Epoch: 4/10... Training loss: 0.1559
# Epoch: 4/10... Training loss: 0.1663
# Epoch: 4/10... Training loss: 0.1663
# Epoch: 4/10... Training loss: 0.1617
# Epoch: 4/10... Training loss: 0.1628
# Epoch: 4/10... Training loss: 0.1650
# Epoch: 4/10... Training loss: 0.1647
# Epoch: 4/10... Training loss: 0.1644
# Epoch: 4/10... Training loss: 0.1578
# Epoch: 4/10... Training loss: 0.1604
# Epoch: 4/10... Training loss: 0.1601
# Epoch: 4/10... Training loss: 0.1604
# Epoch: 4/10... Training loss: 0.1615
# Epoch: 4/10... Training loss: 0.1612
# Epoch: 4/10... Training loss: 0.1649
# Epoch: 4/10... Training loss: 0.1597
# Epoch: 4/10... Training loss: 0.1641
# Epoch: 4/10... Training loss: 0.1646
# Epoch: 4/10... Training loss: 0.1648
# Epoch: 4/10... Training loss: 0.1632
# Epoch: 4/10... Training loss: 0.1650
# Epoch: 4/10... Training loss: 0.1639
# Epoch: 4/10... Training loss: 0.1583
# Epoch: 4/10... Training loss: 0.1626
# Epoch: 4/10... Training loss: 0.1652
# Epoch: 4/10... Training loss: 0.1629
# Epoch: 4/10... Training loss: 0.1646
# Epoch: 4/10... Training loss: 0.1608
# Epoch: 4/10... Training loss: 0.1660
# Epoch: 4/10... Training loss: 0.1601
# Epoch: 4/10... Training loss: 0.1641
# Epoch: 4/10... Training loss: 0.1620
# Epoch: 4/10... Training loss: 0.1657
# Epoch: 4/10... Training loss: 0.1711
# Epoch: 4/10... Training loss: 0.1661
# Epoch: 4/10... Training loss: 0.1601
# Epoch: 4/10... Training loss: 0.1644
# Epoch: 4/10... Training loss: 0.1656
# Epoch: 4/10... Training loss: 0.1632
# Epoch: 4/10... Training loss: 0.1586
# Epoch: 4/10... Training loss: 0.1629
# Epoch: 4/10... Training loss: 0.1619
# Epoch: 4/10... Training loss: 0.1607
# Epoch: 4/10... Training loss: 0.1622
# Epoch: 4/10... Training loss: 0.1643
# Epoch: 4/10... Training loss: 0.1633
# Epoch: 4/10... Training loss: 0.1595
# Epoch: 4/10... Training loss: 0.1587
# Epoch: 4/10... Training loss: 0.1626
# Epoch: 4/10... Training loss: 0.1579
# Epoch: 4/10... Training loss: 0.1599
# Epoch: 4/10... Training loss: 0.1646
# Epoch: 4/10... Training loss: 0.1646
# Epoch: 4/10... Training loss: 0.1617
# Epoch: 4/10... Training loss: 0.1572
# Epoch: 4/10... Training loss: 0.1598
# Epoch: 4/10... Training loss: 0.1618
# Epoch: 4/10... Training loss: 0.1620
# Epoch: 4/10... Training loss: 0.1676
# Epoch: 4/10... Training loss: 0.1666
# Epoch: 4/10... Training loss: 0.1639
# Epoch: 4/10... Training loss: 0.1631
# Epoch: 4/10... Training loss: 0.1567
# Epoch: 4/10... Training loss: 0.1676
# Epoch: 4/10... Training loss: 0.1654
# Epoch: 4/10... Training loss: 0.1644
# Epoch: 4/10... Training loss: 0.1622
# Epoch: 4/10... Training loss: 0.1657
# Epoch: 4/10... Training loss: 0.1549
# Epoch: 4/10... Training loss: 0.1666
# Epoch: 4/10... Training loss: 0.1621
# Epoch: 4/10... Training loss: 0.1661
# Epoch: 4/10... Training loss: 0.1640
# Epoch: 5/10... Training loss: 0.1585
# Epoch: 5/10... Training loss: 0.1604
# Epoch: 5/10... Training loss: 0.1569
# Epoch: 5/10... Training loss: 0.1641
# Epoch: 5/10... Training loss: 0.1598
# Epoch: 5/10... Training loss: 0.1694
# Epoch: 5/10... Training loss: 0.1606
# Epoch: 5/10... Training loss: 0.1610
# Epoch: 5/10... Training loss: 0.1613
# Epoch: 5/10... Training loss: 0.1572
# Epoch: 5/10... Training loss: 0.1603
# Epoch: 5/10... Training loss: 0.1555
# Epoch: 5/10... Training loss: 0.1585
# Epoch: 5/10... Training loss: 0.1606
# Epoch: 5/10... Training loss: 0.1640
# Epoch: 5/10... Training loss: 0.1580
# Epoch: 5/10... Training loss: 0.1602
# Epoch: 5/10... Training loss: 0.1623
# Epoch: 5/10... Training loss: 0.1610
# Epoch: 5/10... Training loss: 0.1587
# Epoch: 5/10... Training loss: 0.1586
# Epoch: 5/10... Training loss: 0.1600
# Epoch: 5/10... Training loss: 0.1604
# Epoch: 5/10... Training loss: 0.1624
# Epoch: 5/10... Training loss: 0.1672
# Epoch: 5/10... Training loss: 0.1650
# Epoch: 5/10... Training loss: 0.1563
# Epoch: 5/10... Training loss: 0.1595
# Epoch: 5/10... Training loss: 0.1629
# Epoch: 5/10... Training loss: 0.1650
# Epoch: 5/10... Training loss: 0.1658
# Epoch: 5/10... Training loss: 0.1649
# Epoch: 5/10... Training loss: 0.1669
# Epoch: 5/10... Training loss: 0.1599
# Epoch: 5/10... Training loss: 0.1619
# Epoch: 5/10... Training loss: 0.1620
# Epoch: 5/10... Training loss: 0.1560
# Epoch: 5/10... Training loss: 0.1614
# Epoch: 5/10... Training loss: 0.1611
# Epoch: 5/10... Training loss: 0.1631
# Epoch: 5/10... Training loss: 0.1677
# Epoch: 5/10... Training loss: 0.1594
# Epoch: 5/10... Training loss: 0.1622
# Epoch: 5/10... Training loss: 0.1610
# Epoch: 5/10... Training loss: 0.1617
# Epoch: 5/10... Training loss: 0.1612
# Epoch: 5/10... Training loss: 0.1557
# Epoch: 5/10... Training loss: 0.1594
# Epoch: 5/10... Training loss: 0.1615
# Epoch: 5/10... Training loss: 0.1620
# Epoch: 5/10... Training loss: 0.1639
# Epoch: 5/10... Training loss: 0.1598
# Epoch: 5/10... Training loss: 0.1646
# Epoch: 5/10... Training loss: 0.1606
# Epoch: 5/10... Training loss: 0.1531
# Epoch: 5/10... Training loss: 0.1666
# Epoch: 5/10... Training loss: 0.1635
# Epoch: 5/10... Training loss: 0.1671
# Epoch: 5/10... Training loss: 0.1630
# Epoch: 5/10... Training loss: 0.1604
# Epoch: 5/10... Training loss: 0.1601
# Epoch: 5/10... Training loss: 0.1634
# Epoch: 5/10... Training loss: 0.1636
# Epoch: 5/10... Training loss: 0.1609
# Epoch: 5/10... Training loss: 0.1644
# Epoch: 5/10... Training loss: 0.1552
# Epoch: 5/10... Training loss: 0.1633
# Epoch: 5/10... Training loss: 0.1587
# Epoch: 5/10... Training loss: 0.1597
# Epoch: 5/10... Training loss: 0.1530
# Epoch: 5/10... Training loss: 0.1654
# Epoch: 5/10... Training loss: 0.1689
# Epoch: 5/10... Training loss: 0.1622
# Epoch: 5/10... Training loss: 0.1605
# Epoch: 5/10... Training loss: 0.1621
# Epoch: 5/10... Training loss: 0.1623
# Epoch: 5/10... Training loss: 0.1569
# Epoch: 5/10... Training loss: 0.1547
# Epoch: 5/10... Training loss: 0.1593
# Epoch: 5/10... Training loss: 0.1644
# Epoch: 5/10... Training loss: 0.1521
# Epoch: 5/10... Training loss: 0.1572
# Epoch: 5/10... Training loss: 0.1603
# Epoch: 5/10... Training loss: 0.1610
# Epoch: 5/10... Training loss: 0.1586
# Epoch: 5/10... Training loss: 0.1597
# Epoch: 5/10... Training loss: 0.1608
# Epoch: 5/10... Training loss: 0.1628
# Epoch: 5/10... Training loss: 0.1604
# Epoch: 5/10... Training loss: 0.1606
# Epoch: 5/10... Training loss: 0.1573
# Epoch: 5/10... Training loss: 0.1554
# Epoch: 5/10... Training loss: 0.1563
# Epoch: 5/10... Training loss: 0.1578
# Epoch: 5/10... Training loss: 0.1644
# Epoch: 5/10... Training loss: 0.1653
# Epoch: 5/10... Training loss: 0.1521
# ...
# Epoch: 9/10... Training loss: 0.1436
# Epoch: 9/10... Training loss: 0.1405
# Epoch: 9/10... Training loss: 0.1432
# Epoch: 9/10... Training loss: 0.1419
# Epoch: 9/10... Training loss: 0.1432
# Epoch: 9/10... Training loss: 0.1457
# Epoch: 9/10... Training loss: 0.1415
# Epoch: 9/10... Training loss: 0.1348
# Epoch: 9/10... Training loss: 0.1455
# Epoch: 9/10... Training loss: 0.1436
# Epoch: 9/10... Training loss: 0.1465
# Epoch: 9/10... Training loss: 0.1413
# Epoch: 9/10... Training loss: 0.1439
# Epoch: 9/10... Training loss: 0.1423
# Epoch: 9/10... Training loss: 0.1456
# Epoch: 9/10... Training loss: 0.1436
# Epoch: 9/10... Training loss: 0.1461
# Epoch: 9/10... Training loss: 0.1461
# Epoch: 9/10... Training loss: 0.1383
# Epoch: 9/10... Training loss: 0.1434
# Epoch: 9/10... Training loss: 0.1451
# Epoch: 9/10... Training loss: 0.1497
# Epoch: 9/10... Training loss: 0.1461
# Epoch: 9/10... Training loss: 0.1461
# Epoch: 9/10... Training loss: 0.1441
# Epoch: 9/10... Training loss: 0.1517
# Epoch: 9/10... Training loss: 0.1481
# Epoch: 9/10... Training loss: 0.1462
# Epoch: 9/10... Training loss: 0.1424
# Epoch: 9/10... Training loss: 0.1414
# Epoch: 9/10... Training loss: 0.1416
# Epoch: 9/10... Training loss: 0.1459
# Epoch: 9/10... Training loss: 0.1489
# Epoch: 9/10... Training loss: 0.1431
# Epoch: 9/10... Training loss: 0.1469
# Epoch: 9/10... Training loss: 0.1408
# Epoch: 9/10... Training loss: 0.1467
# Epoch: 9/10... Training loss: 0.1437
# Epoch: 9/10... Training loss: 0.1371
# Epoch: 9/10... Training loss: 0.1478
# Epoch: 9/10... Training loss: 0.1440
# Epoch: 9/10... Training loss: 0.1454
# Epoch: 9/10... Training loss: 0.1422
# Epoch: 9/10... Training loss: 0.1433
# Epoch: 9/10... Training loss: 0.1419
# Epoch: 9/10... Training loss: 0.1413
# Epoch: 9/10... Training loss: 0.1427
# Epoch: 9/10... Training loss: 0.1444
# Epoch: 9/10... Training loss: 0.1413
# Epoch: 9/10... Training loss: 0.1473
# Epoch: 9/10... Training loss: 0.1448
# Epoch: 9/10... Training loss: 0.1419
# Epoch: 9/10... Training loss: 0.1438
# Epoch: 9/10... Training loss: 0.1485
# Epoch: 9/10... Training loss: 0.1434
# Epoch: 9/10... Training loss: 0.1461
# Epoch: 9/10... Training loss: 0.1456
# Epoch: 9/10... Training loss: 0.1469
# Epoch: 9/10... Training loss: 0.1465
# Epoch: 9/10... Training loss: 0.1542
# Epoch: 9/10... Training loss: 0.1449
# Epoch: 9/10... Training loss: 0.1452
# Epoch: 9/10... Training loss: 0.1456
# Epoch: 9/10... Training loss: 0.1429
# Epoch: 9/10... Training loss: 0.1373
# Epoch: 9/10... Training loss: 0.1432
# Epoch: 9/10... Training loss: 0.1445
# Epoch: 9/10... Training loss: 0.1408
# Epoch: 9/10... Training loss: 0.1487
# Epoch: 9/10... Training loss: 0.1440
# Epoch: 9/10... Training loss: 0.1387
# Epoch: 9/10... Training loss: 0.1417
# Epoch: 9/10... Training loss: 0.1484
# Epoch: 9/10... Training loss: 0.1445
# Epoch: 9/10... Training loss: 0.1418
# Epoch: 9/10... Training loss: 0.1440
# Epoch: 9/10... Training loss: 0.1430
# Epoch: 9/10... Training loss: 0.1504
# Epoch: 9/10... Training loss: 0.1488
# Epoch: 9/10... Training loss: 0.1469
# Epoch: 9/10... Training loss: 0.1496
# Epoch: 9/10... Training loss: 0.1445
# Epoch: 9/10... Training loss: 0.1460
# Epoch: 9/10... Training loss: 0.1438
# Epoch: 9/10... Training loss: 0.1437
# Epoch: 9/10... Training loss: 0.1429
# Epoch: 9/10... Training loss: 0.1421
# Epoch: 9/10... Training loss: 0.1473
# Epoch: 9/10... Training loss: 0.1415
# Epoch: 9/10... Training loss: 0.1426
# Epoch: 9/10... Training loss: 0.1430
# Epoch: 9/10... Training loss: 0.1442
# Epoch: 9/10... Training loss: 0.1412
# Epoch: 9/10... Training loss: 0.1453
# Epoch: 9/10... Training loss: 0.1446
# Epoch: 9/10... Training loss: 0.1477
# Epoch: 9/10... Training loss: 0.1489
# Epoch: 9/10... Training loss: 0.1492
# Epoch: 9/10... Training loss: 0.1438
# Epoch: 9/10... Training loss: 0.1438
# Epoch: 9/10... Training loss: 0.1419
# Epoch: 9/10... Training loss: 0.1433
# Epoch: 9/10... Training loss: 0.1438
# Epoch: 9/10... Training loss: 0.1453
# Epoch: 9/10... Training loss: 0.1418
# Epoch: 9/10... Training loss: 0.1450
# Epoch: 9/10... Training loss: 0.1456
# Epoch: 9/10... Training loss: 0.1424
# Epoch: 9/10... Training loss: 0.1420
# Epoch: 9/10... Training loss: 0.1465
# Epoch: 9/10... Training loss: 0.1483
# Epoch: 9/10... Training loss: 0.1491
# Epoch: 9/10... Training loss: 0.1446
# Epoch: 9/10... Training loss: 0.1464
# Epoch: 9/10... Training loss: 0.1474
# Epoch: 9/10... Training loss: 0.1439
# Epoch: 9/10... Training loss: 0.1427
# Epoch: 9/10... Training loss: 0.1495
# Epoch: 9/10... Training loss: 0.1447
# Epoch: 9/10... Training loss: 0.1442
# Epoch: 9/10... Training loss: 0.1417
# Epoch: 9/10... Training loss: 0.1482
# Epoch: 9/10... Training loss: 0.1439
# Epoch: 9/10... Training loss: 0.1369
# Epoch: 10/10... Training loss: 0.1406
# Epoch: 10/10... Training loss: 0.1439
# Epoch: 10/10... Training loss: 0.1428
# Epoch: 10/10... Training loss: 0.1431
# Epoch: 10/10... Training loss: 0.1448
# Epoch: 10/10... Training loss: 0.1415
# Epoch: 10/10... Training loss: 0.1414
# Epoch: 10/10... Training loss: 0.1489
# Epoch: 10/10... Training loss: 0.1378
# Epoch: 10/10... Training loss: 0.1473
# Epoch: 10/10... Training loss: 0.1461
# Epoch: 10/10... Training loss: 0.1497
# Epoch: 10/10... Training loss: 0.1430
# Epoch: 10/10... Training loss: 0.1388
# Epoch: 10/10... Training loss: 0.1433
# Epoch: 10/10... Training loss: 0.1489
# Epoch: 10/10... Training loss: 0.1423
# Epoch: 10/10... Training loss: 0.1465
# Epoch: 10/10... Training loss: 0.1476
# Epoch: 10/10... Training loss: 0.1392
# Epoch: 10/10... Training loss: 0.1397
# Epoch: 10/10... Training loss: 0.1490
# Epoch: 10/10... Training loss: 0.1470
# Epoch: 10/10... Training loss: 0.1454
# Epoch: 10/10... Training loss: 0.1499
# Epoch: 10/10... Training loss: 0.1457
# Epoch: 10/10... Training loss: 0.1385
# Epoch: 10/10... Training loss: 0.1465
# Epoch: 10/10... Training loss: 0.1430
# Epoch: 10/10... Training loss: 0.1430
# Epoch: 10/10... Training loss: 0.1450
# Epoch: 10/10... Training loss: 0.1412
# Epoch: 10/10... Training loss: 0.1440
# Epoch: 10/10... Training loss: 0.1381
# Epoch: 10/10... Training loss: 0.1420
# Epoch: 10/10... Training loss: 0.1472
# Epoch: 10/10... Training loss: 0.1430
# Epoch: 10/10... Training loss: 0.1480
# Epoch: 10/10... Training loss: 0.1428
# Epoch: 10/10... Training loss: 0.1454
# Epoch: 10/10... Training loss: 0.1438
# Epoch: 10/10... Training loss: 0.1422
# Epoch: 10/10... Training loss: 0.1393
# Epoch: 10/10... Training loss: 0.1423
# Epoch: 10/10... Training loss: 0.1446
# Epoch: 10/10... Training loss: 0.1494
# Epoch: 10/10... Training loss: 0.1475
# Epoch: 10/10... Training loss: 0.1399
# Epoch: 10/10... Training loss: 0.1415
# Epoch: 10/10... Training loss: 0.1443
# Epoch: 10/10... Training loss: 0.1439
# Epoch: 10/10... Training loss: 0.1491
# Epoch: 10/10... Training loss: 0.1426
# Epoch: 10/10... Training loss: 0.1468
# Epoch: 10/10... Training loss: 0.1409
# Epoch: 10/10... Training loss: 0.1426
# Epoch: 10/10... Training loss: 0.1427
# Epoch: 10/10... Training loss: 0.1399
# Epoch: 10/10... Training loss: 0.1481
# Epoch: 10/10... Training loss: 0.1442
# Epoch: 10/10... Training loss: 0.1414
# Epoch: 10/10... Training loss: 0.1489
# Epoch: 10/10... Training loss: 0.1486
# Epoch: 10/10... Training loss: 0.1405
# Epoch: 10/10... Training loss: 0.1441
# Epoch: 10/10... Training loss: 0.1476
# Epoch: 10/10... Training loss: 0.1421
# Epoch: 10/10... Training loss: 0.1496
# Epoch: 10/10... Training loss: 0.1447
# Epoch: 10/10... Training loss: 0.1474
# Epoch: 10/10... Training loss: 0.1459
# Epoch: 10/10... Training loss: 0.1410
# Epoch: 10/10... Training loss: 0.1385
# Epoch: 10/10... Training loss: 0.1415
# Epoch: 10/10... Training loss: 0.1420
# Epoch: 10/10... Training loss: 0.1446
# Epoch: 10/10... Training loss: 0.1415
# Epoch: 10/10... Training loss: 0.1399
# Epoch: 10/10... Training loss: 0.1405
# Epoch: 10/10... Training loss: 0.1487
# Epoch: 10/10... Training loss: 0.1454
# Epoch: 10/10... Training loss: 0.1416
# Epoch: 10/10... Training loss: 0.1406
# Epoch: 10/10... Training loss: 0.1470
# Epoch: 10/10... Training loss: 0.1418
# Epoch: 10/10... Training loss: 0.1425
# Epoch: 10/10... Training loss: 0.1419
# Epoch: 10/10... Training loss: 0.1459
# Epoch: 10/10... Training loss: 0.1462
# Epoch: 10/10... Training loss: 0.1418
# Epoch: 10/10... Training loss: 0.1404
# Epoch: 10/10... Training loss: 0.1484
# Epoch: 10/10... Training loss: 0.1455
# Epoch: 10/10... Training loss: 0.1466
# Epoch: 10/10... Training loss: 0.1421
# Epoch: 10/10... Training loss: 0.1450
# Epoch: 10/10... Training loss: 0.1424
# Epoch: 10/10... Training loss: 0.1491
# Epoch: 10/10... Training loss: 0.1438
# Epoch: 10/10... Training loss: 0.1452
# Epoch: 10/10... Training loss: 0.1439
# Epoch: 10/10... Training loss: 0.1421
# Epoch: 10/10... Training loss: 0.1473
# Epoch: 10/10... Training loss: 0.1458
# Epoch: 10/10... Training loss: 0.1417
# Epoch: 10/10... Training loss: 0.1427
# Epoch: 10/10... Training loss: 0.1423
# Epoch: 10/10... Training loss: 0.1442
# Epoch: 10/10... Training loss: 0.1442
# Epoch: 10/10... Training loss: 0.1481
# Epoch: 10/10... Training loss: 0.1423
# Epoch: 10/10... Training loss: 0.1415
# Epoch: 10/10... Training loss: 0.1446
# Epoch: 10/10... Training loss: 0.1460
# Epoch: 10/10... Training loss: 0.1416
# Epoch: 10/10... Training loss: 0.1438
# Epoch: 10/10... Training loss: 0.1476
# Epoch: 10/10... Training loss: 0.1452
# Epoch: 10/10... Training loss: 0.1419
# Epoch: 10/10... Training loss: 0.1400
# Epoch: 10/10... Training loss: 0.1421
# Epoch: 10/10... Training loss: 0.1482
# Epoch: 10/10... Training loss: 0.1479
# Epoch: 10/10... Training loss: 0.1432
# Epoch: 10/10... Training loss: 0.1449
# Epoch: 10/10... Training loss: 0.1416
# Epoch: 10/10... Training loss: 0.1437
# Epoch: 10/10... Training loss: 0.1419
# Epoch: 10/10... Training loss: 0.1420
# Epoch: 10/10... Training loss: 0.1471
# Epoch: 10/10... Training loss: 0.1431
# Epoch: 10/10... Training loss: 0.1440
# Epoch: 10/10... Training loss: 0.1448
# Epoch: 10/10... Training loss: 0.1422
# Epoch: 10/10... Training loss: 0.1399
# Epoch: 10/10... Training loss: 0.1383
# Epoch: 10/10... Training loss: 0.1379
# Epoch: 10/10... Training loss: 0.1470
# Epoch: 10/10... Training loss: 0.1428
# Epoch: 10/10... Training loss: 0.1450
# Epoch: 10/10... Training loss: 0.1411
# Epoch: 10/10... Training loss: 0.1433
# Epoch: 10/10... Training loss: 0.1471
# Epoch: 10/10... Training loss: 0.1412
# Epoch: 10/10... Training loss: 0.1420
# Epoch: 10/10... Training loss: 0.1421
# Epoch: 10/10... Training loss: 0.1375
# Epoch: 10/10... Training loss: 0.1418
# Epoch: 10/10... Training loss: 0.1392
# Epoch: 10/10... Training loss: 0.1419
# Epoch: 10/10... Training loss: 0.1406
# Epoch: 10/10... Training loss: 0.1471
# Epoch: 10/10... Training loss: 0.1429
# Epoch: 10/10... Training loss: 0.1401
# Epoch: 10/10... Training loss: 0.1364
# Epoch: 10/10... Training loss: 0.1439
# Epoch: 10/10... Training loss: 0.1448
# Epoch: 10/10... Training loss: 0.1510
# Epoch: 10/10... Training loss: 0.1418
# Epoch: 10/10... Training loss: 0.1473
# Epoch: 10/10... Training loss: 0.1398
# Epoch: 10/10... Training loss: 0.1423
# Epoch: 10/10... Training loss: 0.1457
# Epoch: 10/10... Training loss: 0.1385
# Epoch: 10/10... Training loss: 0.1415
# Epoch: 10/10... Training loss: 0.1455
# Epoch: 10/10... Training loss: 0.1438
# Epoch: 10/10... Training loss: 0.1413
# Epoch: 10/10... Training loss: 0.1388
# Epoch: 10/10... Training loss: 0.1447
# Epoch: 10/10... Training loss: 0.1443
# Epoch: 10/10... Training loss: 0.1406
# Epoch: 10/10... Training loss: 0.1426
# Epoch: 10/10... Training loss: 0.1410
# Epoch: 10/10... Training loss: 0.1495
# Epoch: 10/10... Training loss: 0.1396
# Epoch: 10/10... Training loss: 0.1429
# Epoch: 10/10... Training loss: 0.1488
# Epoch: 10/10... Training loss: 0.1431
# Epoch: 10/10... Training loss: 0.1445
# Epoch: 10/10... Training loss: 0.1418
# Epoch: 10/10... Training loss: 0.1436
# Epoch: 10/10... Training loss: 0.1480
# Epoch: 10/10... Training loss: 0.1475
# Epoch: 10/10... Training loss: 0.1451
# Epoch: 10/10... Training loss: 0.1429
# Epoch: 10/10... Training loss: 0.1409
# Epoch: 10/10... Training loss: 0.1496
# Epoch: 10/10... Training loss: 0.1440
# Epoch: 10/10... Training loss: 0.1453
# Epoch: 10/10... Training loss: 0.1457
# Epoch: 10/10... Training loss: 0.1389
# Epoch: 10/10... Training loss: 0.1482
# Epoch: 10/10... Training loss: 0.1409
# Epoch: 10/10... Training loss: 0.1477
# Epoch: 10/10... Training loss: 0.1472
# Epoch: 10/10... Training loss: 0.1402
# Epoch: 10/10... Training loss: 0.1484
# Epoch: 10/10... Training loss: 0.1492
# Epoch: 10/10... Training loss: 0.1454
# Epoch: 10/10... Training loss: 0.1406
# Epoch: 10/10... Training loss: 0.1431
# Epoch: 10/10... Training loss: 0.1442
# Epoch: 10/10... Training loss: 0.1371
# Epoch: 10/10... Training loss: 0.1465
# Epoch: 10/10... Training loss: 0.1352
# Epoch: 10/10... Training loss: 0.1472
# Epoch: 10/10... Training loss: 0.1452
# Epoch: 10/10... Training loss: 0.1421
# Epoch: 10/10... Training loss: 0.1378
# Epoch: 10/10... Training loss: 0.1441
# Epoch: 10/10... Training loss: 0.1375
# Epoch: 10/10... Training loss: 0.1450
# Epoch: 10/10... Training loss: 0.1415
# Epoch: 10/10... Training loss: 0.1398
# Epoch: 10/10... Training loss: 0.1402
# Epoch: 10/10... Training loss: 0.1372
# Epoch: 10/10... Training loss: 0.1453
# Epoch: 10/10... Training loss: 0.1372
# Epoch: 10/10... Training loss: 0.1491
# Epoch: 10/10... Training loss: 0.1410
# Epoch: 10/10... Training loss: 0.1403
# Epoch: 10/10... Training loss: 0.1402
# Epoch: 10/10... Training loss: 0.1326
# Epoch: 10/10... Training loss: 0.1446
# Epoch: 10/10... Training loss: 0.1406
# Epoch: 10/10... Training loss: 0.1417
# Epoch: 10/10... Training loss: 0.1391
# Epoch: 10/10... Training loss: 0.1452
# Epoch: 10/10... Training loss: 0.1401
# Epoch: 10/10... Training loss: 0.1459
# Epoch: 10/10... Training loss: 0.1382
# Epoch: 10/10... Training loss: 0.1421
# Epoch: 10/10... Training loss: 0.1418
# Epoch: 10/10... Training loss: 0.1429
# Epoch: 10/10... Training loss: 0.1448
# Epoch: 10/10... Training loss: 0.1399
# Epoch: 10/10... Training loss: 0.1402
# Epoch: 10/10... Training loss: 0.1436
# Epoch: 10/10... Training loss: 0.1503
# Epoch: 10/10... Training loss: 0.1438
# Epoch: 10/10... Training loss: 0.1441
# Epoch: 10/10... Training loss: 0.1424
# Epoch: 10/10... Training loss: 0.1387
# Epoch: 10/10... Training loss: 0.1382
# Epoch: 10/10... Training loss: 0.1415
# Epoch: 10/10... Training loss: 0.1476
# Epoch: 10/10... Training loss: 0.1452
# Epoch: 10/10... Training loss: 0.1425
# Epoch: 10/10... Training loss: 0.1445
# Epoch: 10/10... Training loss: 0.1433
# Epoch: 10/10... Training loss: 0.1474
# Epoch: 10/10... Training loss: 0.1393
# Epoch: 10/10... Training loss: 0.1403
# Epoch: 10/10... Training loss: 0.1422
# Epoch: 10/10... Training loss: 0.1488
# Epoch: 10/10... Training loss: 0.1370
# Epoch: 10/10... Training loss: 0.1443
# Epoch: 10/10... Training loss: 0.1432
# Epoch: 10/10... Training loss: 0.1396
# Epoch: 10/10... Training loss: 0.1382
# Epoch: 10/10... Training loss: 0.1445
# Epoch: 10/10... Training loss: 0.1421
# Epoch: 10/10... Training loss: 0.1427
# Epoch: 10/10... Training loss: 0.1448
# Epoch: 10/10... Training loss: 0.1448
# Epoch: 10/10... Training loss: 0.1430
# Epoch: 10/10... Training loss: 0.1478
# Epoch: 10/10... Training loss: 0.1400
# Epoch: 10/10... Training loss: 0.1408
# Epoch: 10/10... Training loss: 0.1389
# Epoch: 10/10... Training loss: 0.1390
# Epoch: 10/10... Training loss: 0.1465
# Epoch: 10/10... Training loss: 0.1427
# Epoch: 10/10... Training loss: 0.1389
# Epoch: 10/10... Training loss: 0.1379
# Epoch: 10/10... Training loss: 0.1371
# Epoch: 10/10... Training loss: 0.1437
# Epoch: 10/10... Training loss: 0.1371
# Epoch: 10/10... Training loss: 0.1475
# Epoch: 10/10... Training loss: 0.1425
# Epoch: 10/10... Training loss: 0.1468
# Epoch: 10/10... Training loss: 0.1477
# Epoch: 10/10... Training loss: 0.1412
# Epoch: 10/10... Training loss: 0.1411
# Epoch: 10/10... Training loss: 0.1453
# Epoch: 10/10... Training loss: 0.1371
# Epoch: 10/10... Training loss: 0.1354
# Epoch: 10/10... Training loss: 0.1390
# Epoch: 10/10... Training loss: 0.1404
# Epoch: 10/10... Training loss: 0.1390
# Epoch: 10/10... Training loss: 0.1426
# Epoch: 10/10... Training loss: 0.1443
# Epoch: 10/10... Training loss: 0.1418
# Epoch: 10/10... Training loss: 0.1362
# Epoch: 10/10... Training loss: 0.1477
# Epoch: 10/10... Training loss: 0.1429
# Epoch: 10/10... Training loss: 0.1446
# Epoch: 10/10... Training loss: 0.1403
# Epoch: 10/10... Training loss: 0.1438

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(20,4))
in_imgs = mnist.test.images[:10]
reconstructed = sess.run(decoded, feed_dict={inputs_: in_imgs.reshape((10, 28, 28, 1))})

for images, row in zip([in_imgs, reconstructed], axes):
    for img, ax in zip(images, row):
        ax.imshow(img.reshape((28, 28)), cmap='Greys_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)


fig.tight_layout(pad=0.1)

# %%
sess.close()

# %% [markdown]
# ## Denoising
#
# As I've mentioned before, autoencoders like the ones you've built so far aren't too useful in practive. However, they can be used to denoise images quite successfully just by training the network on noisy images. We can create the noisy images ourselves by adding Gaussian noise to the training images, then clipping the values to be between 0 and 1. We'll use noisy images as input and the original, clean images as targets. Here's an example of the noisy images I generated and the denoised images.
#
# ![Denoising autoencoder](assets/denoising.png)
#
#
# Since this is a harder problem for the network, we'll want to use deeper convolutional layers here, more feature maps. I suggest something like 32-32-16 for the depths of the convolutional layers in the encoder, and the same depths going backward through the decoder. Otherwise the architecture is the same as before.
#
# > **Exercise:** Build the network for the denoising autoencoder. It's the same as before, but with deeper layers. I suggest 32-32-16 for the depths, but you can play with these numbers, or add more layers.

# %%
learning_rate = 0.001
inputs_ = tf.placeholder(tf.float32, (None, 28, 28, 1), name='inputs')
targets_ = tf.placeholder(tf.float32, (None, 28, 28, 1), name='targets')

### Encoder
conv1 = tf.layers.conv2d(inputs_, 32, [28, 28], padding='same', activation=tf.nn.relu)
# Now 28x28x32
maxpool1 = tf.layers.max_pooling2d(conv1, [2, 2], 2)
# Now 14x14x32
conv2 = tf.layers.conv2d(maxpool1, 32, [2, 2], padding='same', activation=tf.nn.relu)
# Now 14x14x32
maxpool2 = tf.layers.max_pooling2d(conv2, [2, 2], 2)
# Now 7x7x32
conv3 = tf.layers.conv2d(maxpool2, 16, [2, 2], padding='same', activation=tf.nn.relu)
# Now 7x7x16
encoded = tf.layers.max_pooling2d(conv3, [4, 4], 1)
# Now 4x4x16

### Decoder
upsample1 = tf.image.resize_images(encoded, [7, 7])
# Now 7x7x16
conv4 = tf.layers.conv2d(upsample1, 16, [2, 2], padding='same', activation=tf.nn.relu)
# Now 7x7x16
upsample2 = tf.image.resize_images(conv4, [14, 14])
# Now 14x14x16
conv5 = tf.layers.conv2d(upsample2, 32, [2, 2], padding='same', activation=tf.nn.relu)
# Now 14x14x32
upsample3 = tf.image.resize_images(conv5, [28, 28])
# Now 28x28x32
conv6 = tf.layers.conv2d(upsample3, 32, [28, 28], padding='same', activation=tf.nn.relu)
# Now 28x28x32

logits = tf.layers.conv2d(conv6, 1, [28, 28], padding='same')
#Now 28x28x1

# Pass logits through sigmoid to get reconstructed image
decoded = tf.nn.sigmoid(logits)

# Pass logits through sigmoid and calculate the cross-entropy loss
loss = tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=targets_)

# Get cost and define the optimizer
cost = tf.reduce_mean(loss)
opt = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %%
sess = tf.Session()

# %%
epochs = 100
batch_size = 200
# Set's how much noise we're adding to the MNIST images
noise_factor = 0.5
sess.run(tf.global_variables_initializer())
for e in range(epochs):
    for ii in range(mnist.train.num_examples//batch_size):
        batch = mnist.train.next_batch(batch_size)
        print(batch[1].shape)
        # Get images from the batch
        imgs = batch[0].reshape((-1, 28, 28, 1))
        
        # Add random noise to the input images
        noisy_imgs = imgs + noise_factor * np.random.randn(*imgs.shape)
        # Clip the images to be between 0 and 1
        noisy_imgs = np.clip(noisy_imgs, 0., 1.)
        
        # Noisy images as inputs, original images as targets
        batch_cost, _ = sess.run([cost, opt], feed_dict={inputs_: noisy_imgs,
                                                         targets_: imgs})

        print("Epoch: {}/{}...".format(e+1, epochs),
              "Training loss: {:.4f}".format(batch_cost))

# %% [markdown]
# ## Checking out the performance
#
# Here I'm adding noise to the test images and passing them through the autoencoder. It does a suprisingly great job of removing the noise, even though it's sometimes difficult to tell what the original number is.

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(20,4))
in_imgs = mnist.test.images[:10]
noisy_imgs = in_imgs + noise_factor * np.random.randn(*in_imgs.shape)
noisy_imgs = np.clip(noisy_imgs, 0., 1.)

reconstructed = sess.run(decoded, feed_dict={inputs_: noisy_imgs.reshape((10, 28, 28, 1))})

for images, row in zip([noisy_imgs, reconstructed], axes):
    for img, ax in zip(images, row):
        ax.imshow(img.reshape((28, 28)), cmap='Greys_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

fig.tight_layout(pad=0.1)
